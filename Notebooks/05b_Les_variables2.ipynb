# %% [markdown]
# <div style="padding:20px;background-color:papayawhip;" >
#
# <h3 style="color:chocolate"> <i class="fa fa-info" aria-hidden="true"> </i> &nbsp; Remarque introductive &nbsp;  <i class="fa fa-info" aria-hidden="true"></h3>
# <p> Ce fichier est fait pour être lu sur le site <a href="https://notebook.basthon.fr/"><img src='https://notebook.basthon.fr/assets/efede5218c9087496f16.png' style="border: 0; display:inline; margin: 0 5px; height:30px" alt="Basthon"/></a>. <br>
#
# Si vous l'avez ouvert avec un autre programme, comme Jupyter notebook, vous riquez de rencontrer quelques bugs. <br>
# Veuillez cliquez sur <a href="https://notebook.basthon.fr/">ce lien</a> et y charger ce fichier à l'aide du bouton "Ouvrir"  &nbsp; <i class="fa fa-folder" aria-hidden="true"> </i>
# </p>
# </div>

# %% [markdown]
# # 5.2 Les variables, Types et entrée-sortie

# %% [markdown]
# ## Types de Données
# Python est un langage à typage dynamique, ce qui signifie que vous n'avez pas besoin de spécifier le type de données d'une variable lorsque vous la créez.
#
#
#
# <blockquote class="alert alert-info" style="background-color:rgb(220,240,255); margin:10px 10%;">
#     <p><span style="font-size:1.5em">❔</span> C'est quoi le type d'une variable ? Regardez la vidéo ci-dessous pour une petite introduction sur la notion de type d'une variable.</p>
# </blockquote>
#
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/5zA8_3YDXb4?si=3V95fi6wa24ddwW_" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
#
#
# ### Principaux types de données en Python
# - `int` : pour les nombres entiers
# - `float` : pour les nombres à virgule flottante
# - `str` : pour les chaînes de caractères
# - `bool` : pour les valeurs booléennes (True ou False)
#
# ```python
# # Exemple de différents types de données
# entier = 10
# chaine = "Bonjour"
# chaine_2 = 'Bonjour'
# flottant = 12.85
# booleen = True

# %% [markdown]
# !!! question Quiz
#
# **Que stocke la variable `pi` dans le code suivant ?**
#
# ```python
# pi = 3.14159
#
# ```
#
#
# <form style="margin-top:10pt;" id="quiz1">
#   <label><input type="checkbox" name="A"> Une chaîne de caractère</label><br>
#   <label><input type="checkbox" name="B"> Un entier</label><br>
#   <label><input type="checkbox" name="C" value="correct"> Un nombre à virgule flottante</label><br>
#   <label><input type="checkbox" name="D"> Une valeur booléenne</label>
# </form>
#
# !!!

# %%
# Exécuter pour valider votre réponse et continuer
from _validation import *
ValidateQuiz("quiz1")()

# %% [markdown]
# !!! question Quiz
#
# **En Python, `int` est l'abréviation pour :**
#
#
#
# <form style="margin-top:10pt;" id="quiz2">
#   <label><input type="checkbox" name="A"> international</label><br>
#   <label><input type="checkbox" name="B" value="correct"> integer</label><br>
#   <label><input type="checkbox" name="C"> interne</label><br>
#   <label><input type="checkbox" name="D"> intégrité</label>
# </form>
#
# !!!

# %%
ValidateQuiz("quiz2")() # Exécuter pour valider votre réponse et continuer

# %% [markdown]
# !!! question Question
#
# **Indiquez le type des variables (`int`, `float`, `str`, `bool`) permettant de stocker sur votre smartphone les informations suivantes :**
#
#
#
#
# <form style="margin-top:10pt;"  id="question3">
# <ul>
# 	<li><label>le nom d’un contact : <input type="text" id="str" value=""></label><br></li>
# 	<li><label>l'age d'un contact : <input type="text" id="int" value=""></label><br></li>
# 	<li><label>un SMS : <input type="text" id="str" value=""></label><br></li>
# 	<li><label>le prix d'un croissant : <input type="text" id="float" value=""></label><br></li>
# 	<li><label>le code de votre partage de connexion Wi-Fi : <input type="text" id="str" value=""></label><br></li>
# 	<li><label>le pourcentage affiché de batterie restante :<input type="text" id="int" value=""></label><br></li>
# 	<li><label>ma note à la dernière épreuves de Mathématiques : <input type="text" id="float" value=""></label><br></li>
#     <li><label>si un·e élève est promue : <input type="text" id="bool" value=""></label><br></li>
# </ul>
# </form>
#
# !!!

# %%
ValidateTextInput("question3")()

# %% [markdown]
# !!! info Les erreurs lorsqu'on débute:
#
# <ul>
#     <li>Une chaîne de caractère (str) est toujours encadré par des guillemets (") ou des apostrophes (').
#         Exemple: "Tortue" ou 'Tortue'. Si vous oubliez d'encadrer votre chaîne de caractère par des " ou ', alors Python considèrera la chaîne comme une variable !
#     <li> En Python, on utilise le point (.) pour écrire les nombres décimaux (float) et jamais la virgule, qui a une autre signification.
#         <li> Lors de la création d'une variable, Python fait la différence entre majuscules et minuscules : par exemple compteur ≠ Compteur.
# !!!

# %% [markdown]
# ## La fonction `input()` en Python
#
# ### 1️⃣ À quoi sert `input()` ?
#
# La fonction `input("question")` permet de **poser une question à l’utilisateur·trice** et de **récupérer sa réponse**.L'utilisateur·trice voit le texte question affiché à la console et doit répondre à cette question. Il termine son entrée avec la touche Enter (Entrée).
#
# 👉 Le programme devient **interactif** : il s’adapte à ce que l’utilisateur·trice écrit.
#
# La réponse de l'utilisateur·trice est ensuite mémorisée dans une variable que nous appelons `x` dans cet exemple.
# Ensuite, nous pouvons utiliser cette variable `x` dans la suite du programme, par exemple comme argument dans une fonction `print()`.
#
# ### 2️⃣ Exemple simple

# %%
x = input('Entrez votre nom: ')
print('Bonjour', x)

# %% [markdown]
# !!! note &nbsp; Exercice 1
#
# Ajoutez une troisième question et utilisez la réponse dans un `print()`.
#
# !!!

# %%
nom = input('Entrez votre nom: ')
print('Bonjour', nom)

age = input('Entrez votre âge: ')
print('Très bien', nom, 'vous avez', age, 'ans')

# Compléter ci-dessous

# %% [markdown]
# !!! note &nbsp; Exercice 2
#
# Écrire un programme qui demande le prénom de l’utilisateur·trice, puis, dans une seconde question, son nom de famille, et qui affiche ensuite le message de bienvenue contenant le prénom et le nom saisis.<br>
#
#     `"Bienvenue Prénom Nom"`
#
# !!!

# %% [markdown]
# !!! tip Exécuter pour continuer
#
# !!!

# %% [markdown]
# ## Demander un nombre
#
# La fonction `input()` permet d'obtenir une entrée de l'utilisateur. Mais attention !
# La valeur retournée est une chaine de caractères (de type string `str`). Nous pouvons le prouver avec la fonction `type()`.

# %%
x = input('Entrez un nombre: ')
print(type(x))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>&#9889; A retenir : </b> <br>
#     Une valeur saisie au clavier à l’aide de la fonction input() est <b>toujours de type str</b>, c’est-à-dire une chaîne de caractères.
#
# Autrement dit, dans l’exemple ci-dessus, même si l’utilisateur·trice saisit 892, la variable x contiendra la chaîne de caractères "892" et non le nombre entier 892 de type int.
# </div>

# %% [markdown]
# Pour pouvoir utiliser cette valeur dans un calcul, nous devons la transformer en nombre. Deux possibilités:
# - convertir en nombre entier (int)
# - convertir en nombre flottant (float).
#
# Prenons l'exemple pour convertir une chaine de caractères en un nombre à virgule flottante nous utilisons la fonction de conversion `float()`.

# %%
x = '1.5'
print(type(x))          # la variable x contient une chaîne
print(type(float(x)))   # la fonction float(x) renvoie un nombre

# %% [markdown]
# ### Exemple
#
# On souhaite avoir un programme qui permet de calculer la moyenne de deux nombres qui sont fournis par l'utilisateur. Tester la proposition de programme suivante:

# %%
#Demande à l'utilisateur deux nombres puis calcule et affiche leur somme
nombre1 = input("Taper un premier nombre : ")
nombre2 = input("Taper un deuxième nombre : ")
moyenne = (nombre1 + nombre2)/2
print("La somme de ces deux nombres est ",moyenne)

# %% [markdown]
# On comprend le problème : pour python `nombre1` et `nombre2` sont en fait des chaines de caractères par conséquent, calculer leur moyenne n'a pas de sens !
#
# Pour résoudre ce problème nous devons convertir `nombre1` et `nombre2` en nombre à virgule, cela se fait grâce à l'instruction `float`. Voici le programme corrigé :

# %%
#Demande à l'utilisateur deux nombres puis calcule et affiche leur somme
nombre1 = float(input("Taper un premier nombre : ")) #float() permet de convertir la valeur entrée en flottant
nombre2 = float(input("Taper un deuxième nombre : ")) 
moyenne = (nombre1 + nombre2)/2
print("La moyenne de ces deux nombres est ",moyenne)

# %% [markdown]
# !!! note &nbsp; Exercice 3
#
# Complétez le programme pour afficher la surface du cercle.
#
# !!!

# %%
r = float(input('Entrez le rayon du cercle : '))
pi = 3.14
print()
print('rayon =', r)
print('diamètre =', 2 * r)
print('circonférence =', pi * 2 * r)
print('surface =', ...)

# %% [markdown]
# Nous pouvons également créer des programmes où nous demandons plusieurs valeurs à l'utilisateur. Cette fois, nous permettons seulement l'utilisation de nombres entiers, et donc transformons la chaine obtenue avec `int()` en nombre entier.

# %% [markdown]
# !!! note &nbsp; Exercice 4
#
# Complétez le programme pour afficher le périmètre et la diagonale.
#
# !!!

# %%
from math import sqrt

print('Rectangle')
a = float(input('Entrez la largeur: '))
b = float(input('Entrez la longueur: '))

print('surface =', a * b)
print('périmètre =', ...)
print('diagonale =', ...)

# %% [markdown]
# !!! info utiliser des fonctions mathématiques comme la fonction racine carrée $\sqrt{x}$.
#
# Pour calculer la racine carrée d'un nombre $\sqrt{x}$, il faut utiliser la fonction `sqrt` du module `math`. Pour ce faire, votre programme doit commencer par `from math import sqrt` (pour importer la fonction `sqrt` du module `math`).  Pour l'utiliser, il suffit de mettre la valeur dont on veut trouver la racine en argument de la fonction `sqrt`. Par exemple, l'instruction `print(sqrt(25))` affichera 5.
# !!!

# %% [markdown]
# !!! tip Exécuter pour continuer
#
# !!!

# %% [markdown]
# !!! note &nbsp; Exercice 5
#
# Chacun des programmes suivants devrait demander à l’utilisateur deux nombres, et écrire le produit de ces deux nombres mais il contient au moins une erreur. Corrigez chacun des programmes puis testez les.
#
# **Programme A**
#
# !!!

# %%
int(input("premier nombre: "))
int(input("deuxième nombre: "))
print(premier*deuxième)

# %% [markdown]
# **Programme B**

# %%
x=input("premier nombre: ")
y=input("deuxième nombre: ")
x*y

# %% [markdown]
# **Programme C**

# %%
x=int("premier nombre : ")
y=int("deuxième nombre: ")
z=x*y
print("z")

# %% [markdown]
# !!! note &nbsp; Exercice 6
#
# Complétez le programme Python ci-dessous qui calcule la surface d'un rectangle après avoir demandé sa largeur et sa longueur.
#
#
# Indication: Il faut remplacer les `_____` par ce qu'il convient
#
# !!!

# %%
# Programme pour calculer la surface d'un rectangle à partir de sa longueur et de sa largeur
longueur = _____(input("Entrer la longueur du rectangle : ")) #longueur doit être un flottant utiliser la conversion !
largeur = _____(_____("Entrer la largeur du rectangle : "))
surface = _______*_________
_____("La surface du rectangle est :",___________)

# %% [markdown]
# ## L'indice d'une boucle `for`, une variable gratuite
#
# Il est possible de remplacer le symbole `_` dans une boucle `for` par le nom d’une variable, appelée indice de boucle. Cette variable est initialisée à `0`, puis incrémentée de `1` à chaque itération de la boucle. Par exemple, le programme suivant :
#
# ```python
# k = 0
# for _ in range(10):
#     print(k)
#     k = k + 1
# ```
#
# est équivalent au programme suivant:
# ```python
# for k in range(10):
#     print(k)
# ```

# %% [markdown]
# !!! question Question
#
# **Avez-vous bien compris ?**
#
#
#
#
# <form style="margin-top:10pt;"  id="question4">
# <ul>
# 	<li><label>Combien vaut toujours la variable k au 1er tour de boucle ? <input type="text" id="0" value=""></label><br></li>
# 	<li><label>Combien vaut la variable k au 10ème (et dernier) tour de boucle ? <input type="text" id="9" value=""></label><br></li>
# </ul>
# </form>
#
# !!!

# %%
ValidateTextInput("question4")()

# %% [markdown]
# !!! note &nbsp; Exercice 6.5
#
# Récrire le programme de la table de mutliplication de 7 en utilisant un indice `k` de boucle `for`.
#
# ```python
# n = 0
# for _ in range(10):
#     print(n, " x 7 =", n*7)
#     n = n + 1
# ```
#
# *Indication:*
# **Votre programme doit contenir seulement 2 lignes**
#
# !!!

# %%
# Votre programme ici

# %%
test_5b_6b() # Exécuter pour continuer

# %% [markdown]
# !!! note &nbsp; Exercice 7
#
# Chacun des programmes devrait demander à l’utilisateur·ice un nombre `n`, et écrire les n premiers multiples de 100. Corriger les erreurs de chaque programme afin qu’il fonctionne.
#
#
# **Programme A**
#
# !!!

# %%
n = int(input("Nombre de multiples: "))
for _ in range(n):
    print(x)
    x+100

# %% [markdown]
# **Programme B**

# %%
x = int(input("Nombre de multiples: "))
n = 0
for _ in range(x):
    print(x)
    x = x+100

# %% [markdown]
# **Programme C**

# %%
x = int(input("Nombre de multiples: "))
n = 100
for _ in range(x):
      print(n)
n = n+n

# %% [markdown]
# **Programme D**

# %%
n = int(input("Nombre de multiples: "))
for x in range(n):
    print(n*100)

# %% [markdown]
# **Programme E**

# %%
n = int(input("Nombre de multiples: "))
for x in range(n):
    x = x+100
    print(x*100)

# %% [markdown]
# !!! tip Exécuter pour continuer
#
# !!!

# %% [markdown]
# ## Exercices d'entrainement

# %% [markdown]
# !!! note &nbsp; Exercice 8
#
# Compléter le programme Python qui demande à l’utilisateur un mot, et un nombre n et qui écrit n fois de suite le mot donné par l’utilisateur.
#
# !!!

# %%
n = input(...)
mot = input(...)
for #à compléter
    #à compléter

# %% [markdown]
# !!! note &nbsp; Exercice 9
#
# On considère le programme suivant:
#
# ```python
#
# from turtle import *
#
# n = 10
# angle = int(360 / n)
#
# for k in range(n):
#     forward(100)
#     right(angle)
#
# done()
# ```
#
# 1. Tester le programme ci-dessus, puis modifiez le en définissant une fonction `polygone(lg, n)` qui permet de tracer des polygones réguliers avec `n` côtés et de longueur `lg`. Le programme doit produire la même figure mais en utilisant la fonction  `polygone(lg, n)`.
#
# !!!

# %%
from turtle import *

n = 10
angle = int(360 / n)

for k in range(n):
    forward(100)
    right(angle)

done()

# %% [markdown]
# 2. Modifiez le programme précédant afin d’obtenir un programme qui demande à l’utilisateur⋅trice la taille et le nombre de côtés du polygone régulier puis trace ce polygone.
#
# Exemple d’exécution du programme:
#
# ```
# Quel est la nombre de côtés de votre polygone : 8
# Quelle est la taille de votre polygone : 100
# ```
# qui devrait générer un hexagone de côté 100:

# %%
# votre programme complet...

# %% [markdown]
# !!! note &nbsp; Exercice 10
#
# Compléter le programme pour avoir un programme qui demande un nombre à l’utilisateur⋅trice et qui dessine un carré ayant cette longueur comme côté.
#
# !!!

# %%
from turtle import *

# à compléter

done()

# %% [markdown]
# ## ⚠️ Erreurs fréquentes en Python (à éviter)
#
# Cette section résume les erreurs les plus courantes rencontrées lors des premiers programmes en Python.
#
#
#
# ### 1️⃣ Oublier les guillemets autour d’un texte
#
# ❌ Incorrect :
# ```python
# print(bonjour)
# ```
#
# ✅ Correct :
# ```python
# print("bonjour")
# ```
#
# 👉 Sans guillemets, Python interprète le mot comme le **nom d’une variable**.
#
#
# ### 2️⃣ Oublier que `input()` renvoie toujours une chaîne de caractère (str)
#
# ❌ Incorrect :
# ```python
# age = input("Quel est ton âge ? ")
# print(age + 1)
# ```
#
# ✅ Correct :
# ```python
# age = int(input("Quel est ton âge ? "))
# print(age + 1)
# ```
#
# 👉 La valeur retournée par `input()` est toujours de type **`str`** (texte).
#
#
# ### 3️⃣ Utiliser une virgule au lieu d’un point pour les nombres décimaux
#
# ❌ Incorrect :
# ```python
# x = 3,5
# ```
#
# ✅ Correct :
# ```python
# x = 3.5
# ```
#
# 👉 En Python, les nombres décimaux (`float`) s’écrivent avec un **point**.
#
#
# ### 4️⃣ Confondre majuscules et minuscules dans les noms de variables
#
# ❌ Incorrect :
# ```python
# Compteur = 5
# print(compteur)
# ```
#
# ✅ Correct :
# ```python
# compteur = 5
# print(compteur)
# ```
#
# 👉 Python distingue les **majuscules** et les **minuscules** :
# `compteur` ≠ `Compteur`

# %% [markdown]
# # 🟥  Fin
#
# <div class="alert alert-danger" style="border-left:5px solid #a94442;border-radius: 5px;">
#
# - **Ne pas Oublier de sauvegarder son travail.**
#
# - **Pour effectuer** une sauvegarde personnelle du document obtenu :
#    - utilisez le menu `Fichier / Enregistrer sous…`.
#    - nomez le fichier `variables_suite.ipynb` ou `leçon5b.ipynb`
#    - choisissez de sauver votre fichier dans vos `Documents` dans le bon sous-dossier.
#
#     </div>
#
#
# #### Remarque générale
#
# Ce document c'est inspiré des notebook trouvé sur
# - Les ressources pédagogiques du catalogue modulo https://modulo-info.ch/.
# - Les ressources pédagogiques du [Lycée Mounier](https://info-mounier.fr/snt/python/)
#
# Le notebook est sous license Creative Commons [BY-NC-SA](https://creativecommons.org/licenses/?lang=fr)
# ![Licence Creative Commons](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
