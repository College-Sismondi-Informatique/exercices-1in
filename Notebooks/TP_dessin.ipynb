# %% [markdown]
# # Travail pratique: Dessiner avec des fonctions

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;">1. Objectifs du projet</h2>
# </div>
#
#
# - **Être capable de collaborer** sur un projet informatique.
#   - Pouvoir se répartir le travail, par exemple en identifiant les formes complexes à implémenter sous forme de fonctions Python, et qui peuvent être implémentées séparément.
# - **S'assurer de pouvoir continuer le programme** même si un·e camarade est absent·e durant un cours. Utiliser par exemple un dossier partagé sur le drive.
# - **Être capable de déboguer** un programme (exemple : tester une fonction séparément, utiliser des commentaires pour identifier le problème).
# - **Pouvoir décomposer et structurer** un programme en sous-programmes implémentés par des fonctions.
#   - Avoir un processus de développement cohérent avec cette approche : décomposer le développement en étapes successives avec une validation pour chaque étape.
#   - Chaque forme est implémentée par une fonction avec des paramètres.
#     - Le curseur revient toujours à la position initiale **avec l’orientation initiale**.
# - **Être capable de documenter** un programme avec des commentaires.
# - **Utiliser des boucles** pour factoriser le code, en particulier pour des formes qui se répètent.
#   - Utiliser une variable pour créer des variations dans les répétitions.
# - **Utiliser une entrée** (`input`) pour avoir un programme **interactif**.
#   - Au moins **une valeur numérique**.
# - **Être capable d’utiliser** les différentes fonctions du module Python `turtle` pour tracer des figures avec des épaisseurs, couleurs et formes différentes.
# - **Être capable de vectoriser** un dessin avec « un algorithme ».

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;">2. Cahier des charges</h2>
# </div>
#
# On veut réaliser un dessin respectant (exemples de projets passés). À la fin du projet, les critères suivants doivent être remplis :
# - Dessin original et harmonieux.
# - Au moins **3 formes complexes différentes** (étoile, maison, nuage, etc.), dont **une est répétée avec des variations** (p. ex. : couleur, taille, forme, …).
# - Les formes utilisent **plusieurs couleurs** (traits et remplissages) et des **épaisseurs différentes**.
# - L’utilisateur·ice peut choisir **au moins 2 paramètres** du dessin (**1 choix multiple** et **une entrée libre**).

# %% [markdown]
# <div style="background:#E3F2FD;border-left:6px solid #1976D2;padding:14px;margin:16px 0;">
#   <div style="font-size:20px;font-weight:700;margin-bottom:10px;">
#     Idée de planning – déroulement du projet
#   </div>
#
#   <!-- En-tête -->
#   <div style="display:flex;font-weight:900;background:#BBDEFB;border:1px solid #90CAF9;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;">Semaine</div>
#     <div style="flex:1;padding:10px;">À réaliser</div>
#   </div>
#
#   <!-- Ligne 1 -->
#   <div style="display:flex;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>1</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Idée générale du dessin sur une feuille quadrillée.</div>
#       <div>• Création de l’arrière-plan (spécifier la couleur et la taille de la fenêtre).</div>
#       <div>• Création d’un dossier partagé entre vous.</div>
#       <div>• Dépôt sur Moodle de la <strong>version 1</strong> :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div><code>projet_dessin_prenom1_prenom2_V1.py</code></div>
#         <div><code>idee_dessin_prenom1_prenom2_V1.png</code> (ou autre format)</div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Ligne 2 -->
#   <div style="display:flex;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>2</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• <strong>2 fonctions</strong> dessinant une forme complexe (étoile, maison, nuage, etc.).</div>
#       <div>• Au moins <strong>une des deux</strong> possède <strong>un paramètre</strong>.</div>
#       <div>• Commentaires : but de la fonction et rôle des paramètres.</div>
#       <div>• Introduction d’une <strong>boucle</strong> pour <strong>répéter</strong> une forme.</div>
#     </div>
#   </div>
#
#   <!-- Ligne 3 -->
#   <div style="display:flex;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>3</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Variables au début du programme :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div>– largeur, hauteur, couleur de la fenêtre</div>
#         <div>– nombre de répétitions de la boucle</div>
#       </div>
#       <div style="margin-top:6px;">• Variation dans la boucle (taille, épaisseur, etc.).</div>
#       <div>• Une question à l’utilisateur·ice pour choisir un paramètre (taille, couleur, etc.).</div>
#     </div>
#   </div>
#
#   <!-- Ligne 4 -->
#   <div style="display:flex;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>4</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Poser une <strong>2ᵉ question</strong> permettant de saisir une <strong>valeur numérique</strong>.</div>
#     </div>
#   </div>
#
#   <!-- Ligne 5 -->
#   <div style="display:flex;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>5</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Finaliser le dessin.</div>
#       <div>• Vérifier le cahier des charges complet (3 formes, rendu général, etc.).</div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ### Autres éléments pris en compte dans l’évaluation
# #### 1) Structure du code
# - Le code est structuré de manière correcte :
#   - **1ʳᵉ partie** : import de la librairie `turtle` (et éventuellement de `random`).
#   - **2ᵉ partie** : définition des fonctions.
#   - **3ᵉ partie** : programme principal (production du dessin en appelant les fonctions définies dans la partie 2).
# - Des variables sont utilisées pour les différents paramètres du dessin et les noms des variables/fonctions décrivent correctement ce qu’elles représentent.
# - Des commentaires pertinents sont ajoutés pour décrire votre code (un commentaire d’en-tête, des *docstrings* pour chaque fonction, et des commentaires pour rendre la lecture facile).
# - Chaque fonction est commentée en utilisant une *docstring* (voir l’exemple plus bas).
# - Le programme utilise les boucles à bon escient (le même code n’est pas répété plusieurs fois).
#
# #### 2) Résultat
# - Le programme fonctionne comme attendu (aucune erreur).
# - Originalité : le résultat se démarque des exemples donnés, ce qui indique une bonne compréhension des notions étudiées.
#
# #### 3) Modalités du TP
# - Chaque version hebdomadaire du TP a été rendue à temps sur Moodle.
# - Le fichier est correctement nommé du type : `Projet_dessin_prénoms_des_élèves_versionX.py`.
# - Un commentaire d’en-tête décrit les auteur·ices, les dates et le contenu du fichier.

# %% [markdown]
# ## Grille d’évaluation (actuelle)
# | Critère | Points (élève) | Points totaux |
# |---|:---:|:---:|
# | Être capable de collaborer : l’écriture des différentes fonctions est répartie au sein du groupe. |  | / 1,0 |
# | Le dossier partagé a été créé et partagé entre les membres du groupe et l’enseignant. |  | / 1,0 |
# | **Éléments visuels** : il y a plusieurs formes différentes. |  | / 1,0 |
# | La tortue revient à sa position initiale à la fin. |  | / 2,0 |
# | Les formes sont de plusieurs couleurs ou d’épaisseur différente. |  | / 1,0 |
# | **Structure du code** : le code est structuré correctement (1ʳᵉ partie imports, 2ᵉ partie fonctions, 3ᵉ partie programme). |  | / 1,0 |
# | Le code est structuré avec des fonctions (chaque élément visuel correspond à une fonction). |  | / 3,0 |
# | Le programme utilise les boucles à bon escient (pas de répétitions inutiles). |  | / 3,0 |
# | Il y a une boucle qui répète une forme en faisant varier un paramètre (ex. taille d’un élément de la forme). |  | / 2,0 |
# | Les dimensions de la fenêtre et la couleur de l’arrière-plan sont spécifiées au démarrage avec des variables. |  | / 2,0 |
# | Au moins une des fonctions demande un paramètre d’entrée. |  | / 2,0 |
# | Les noms des variables et des fonctions sont appropriés. |  | / 1,0 |
# | Des commentaires pertinents sont ajoutés (programme compréhensible à la lecture). |  | / 1,0 |
# | Chaque fonction est commentée avec une *docstring* (voir l’exemple ci-dessous). |  | / 2,0 |
# | Un branchement conditionnel (`if`) est utilisé pour traiter la réponse du `input`. |  | / 3,0 |
# | **Fonctionnalité** : au lancement, l’utilisateur saisit un ou plusieurs paramètres utilisés ensuite (ex. nombre de maisons). |  | / 2,0 |
# | **Résultat** : le programme fonctionne comme attendu (aucun bug). |  | / 2,0 |
# | Originalité : le résultat se démarque des exemples et montre une bonne compréhension. |  | / 4,0 |
# | **Modalités** : chaque version hebdomadaire a été rendue à temps sur Moodle. |  | / 2,0 |
# | Avoir rendu les deux notebooks (complétés) sur les variables. |  | / 2,0 |
# | Le programme final a été rendu à temps. |  | / 1,0 |
# | **Total** |  | **/ 40,0** |
#
# **Note (barème fédéral)** : Nombre de points / 40 × 5 + 1
#
# **6,0**

# %% [markdown]
# ## Ancienne grille
# *(Reprise du document d’origine, présentée telle quelle.)*
#
# | Critère | Points (élève) | Points totaux |
# |---|:---:|:---:|
# | **Introduction** : le fichier est correctement nommé. |  | / 1,0 |
# | Le commentaire d’en-tête est correctement rempli. |  | / 1,0 |
# | **Éléments visuels** : il y a plusieurs formes différentes. |  | / 1,0 |
# | Il y a au moins deux formes complexes (étoile, maison, nuage, etc.). |  | / 2,0 |
# | Au moins une forme se répète plusieurs fois. |  | / 1,0 |
# | Les formes sont de plusieurs couleurs ou d’épaisseur différente. |  | / 1,0 |
# | **Structure du code** : le code est structuré correctement (imports, fonctions, programme). |  | / 1,0 |
# | Le code est structuré avec des fonctions (chaque élément visuel correspond à une fonction). |  | / 3,0 |
# | Le programme utilise les boucles à bon escient (pas de répétitions inutiles). |  | / 3,0 |
# | Il y a une boucle qui répète une forme en faisant varier un paramètre. |  | / 2,0 |
# | Les dimensions de la fenêtre et la couleur de l’arrière-plan sont spécifiées avec des variables. |  | / 2,0 |
# | Au moins une des fonctions demande un paramètre d’entrée. |  | / 2,0 |
# | Les noms des variables et des fonctions sont appropriés. |  | / 1,0 |
# | Des commentaires pertinents sont ajoutés (programme compréhensible à la lecture). |  | / 1,0 |
# | Chaque fonction est commentée avec une *docstring*. |  | / 2,0 |
# | Un branchement conditionnel (`if`) traite la réponse du `input`. |  | / 3,0 |
# | **Fonctionnalité** : paramètres demandés au lancement. |  | / 2,0 |
# | **Résultat** : programme sans bug. |  | / 2,0 |
# | Originalité. |  | / 4,0 |
# | **Modalités** : versions hebdomadaires rendues à temps. |  | / 2,0 |
# | Avoir rendu les deux notebooks (complétés) sur les variables. |  | / 2,0 |
# | Programme final rendu à temps. |  | / 1,0 |
# | **Total** |  | **/ 40,0** |
#
# **Note (barème fédéral)** : Nombre de points / 40 × 5 + 1
#
# **6,0**

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;">3. Initialisation et documentation</h2>
# </div>
#
# Pour définir les propriétés de l’arrière-plan, on utilise :

# %%
from turtle import Screen

Screen().setup(300, 400)      # fixe la taille de la fenêtre à 300x400
Screen().bgcolor("couleur")   # fixe la couleur de l’arrière-plan

# %% [markdown]
# ### Docstring
# Chaque fois qu’une fonction est définie, il est demandé d’ajouter un commentaire de type **docstring** (c’est un commentaire encadré par des triple apostrophes `''' ... '''`) qui indique :
# - ce que fait la fonction,
# - si elle a des paramètres,
# - quels sont leurs types,
# - et ce que représentent ces paramètres.
#
# **Exemple :**

# %%
def triangle(lg_cote):
    ''' dessine un triangle équilatéral
    param(s) :
    lg_cote (int) : longueur d'un côté du triangle

    Exemples
    '''
    for i in range(3):
        forward(lg_cote)
        right(120)

# %% [markdown]
# ### Commentaire d’en-tête (obligatoire)
# Votre programme doit commencer avec un commentaire d’en-tête comme celui-ci :

# %%
''' Auteur(s) : votre(vos) nom(s)
Contact(s) : votre(vos) courriel(s)
License : "CC-BY-NC-SA"
Date : la date du jour
Version : 1.0
Description : La description de votre programme
'''

# %% [markdown]
# <div style="
#     background-color:#FFF3E0;
#     border:2px solid #FB8C00;
#     border-radius:8px;
#     padding:14px;
#     margin:20px 0;
# ">
# <h2 style="margin-top:0;">⚠️ Consigne importante (plagiat et règles)</h2>
# <ol>
# <li>De trop grandes similitudes entre le travail de deux groupes seront considérées comme de la fraude et la note de **1** pourrait être attribuée aux deux travaux.</li>
# <li>L’utilisation d’outils utilisant l’IA pour déléguer l’écriture du programme est interdite.</li>
# <li>Les concepts utilisés pour écrire le programme doivent être ceux du cours.</li>
# <li>Utiliser des outils, des fonctions ou des concepts non étudiés en cours, et sans l’accord de l’enseignant, est totalement interdit et pourrait conduire à une note de **1**.</li>
# <li>Reprendre les fonctions de l’exemple n’est pas suffisant. Il faut au minimum modifier ces fonctions, par exemple en ajoutant un paramètre ou en modifiant la forme de maison produite, etc.</li>
# </ol>
# </div>

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;">4. Avancer en dehors des cours</h2>
# </div>
#
#
# Pour avancer en dehors des cours, faites une copie de votre travail à la fin de chaque cours dans un dossier sur le Drive partagé avec votre binôme.
#
# Il y a plusieurs possibilités pour avancer :
# - Utiliser un ordinateur de la bibliothèque.
# - Télécharger et installer **Thonny** sur votre ordinateur à la maison (références du document) :
#   - https://github.com/thonny/thonny/releases
#
# Version actuelle (décembre 2024) : **4.1.7**
# - Pour Windows :
#   - https://github.com/thonny/thonny/releases/download/v4.1.7/thonny-4.1.7.exe
# - Pour MacOS :
#   - https://github.com/thonny/thonny/releases/download/v4.1.7/thonny-4.1.7.pkg

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;">5. Trucs et astuces</h2>
# </div>
#
#
# - En combinant les fonctions `position()` et `goto()`, il est possible d’enregistrer la position de la tortue puis d’y revenir plus tard.
# - Écrire une fonction de déplacement qui déplace la tortue en levant le curseur (`penup/pendown`).
# - `setheading()` permet de remettre le curseur dans la bonne orientation.
# - Mettre en paramètre la position des objets.
