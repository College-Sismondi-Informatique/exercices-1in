# %% [markdown]
# # Travail pratique: Dessiner avec des fonctions
#
# **Accès rapide, cliquer sur le lien**
# 1. [Objectifs du projet](#objectifsProjet)
# 2. [Cahier des charges et évaluation](#cahierDesCharges)
# 3. [Comment avancer en dehors des cours](#avancerSeul)
# 4. [Ce qu'il ne faut pas faire !](#nePasFaire)
# 5. [Planning et tâche à effectuer](#planning)
#     - [Tâches premier rendu](#tachesRendu1)
#     - [Tâches deuxième rendu](#tachesRendu2)
#     - [Tâches troisième rendu](#tachesRendu3)
#     - [Tâches quatrième rendu](#tachesRendu4)
#     - [Tâches rendu final](#tachesRenduFinal)

# %% [markdown]
# <div style="
#     background-color:#FFF3E0;
#     border:2px solid #FB8C00;
#     border-radius:8px;
#     padding:14px;
#     margin:20px 0;
# ">
# <h2 style="margin-top:0;">⚠️ Consigne importante (plagiat et règles)</h2>
# <ol>
#     <li>De <B>trop grandes similitudes</B> entre le travail de deux groupes seront considérées comme de la fraude et la note de <B>1</B> pourrait être attribuée aux deux travaux.</li>
#     <li>L’utilisation d’outils utilisant l’IA pour déléguer l’écriture du programme est <B>interdite.</B></li>
#     <li>Les concepts utilisés pour écrire le programme doivent être ceux du cours.</li>
#     <li>Utiliser des outils, des fonctions ou des concepts non étudiés en cours, et sans l’accord de l’enseignant, est totalement interdit et pourrait conduire à une note de <B>1</B>.</li>
#     <li><B>Reprendre</B> les fonctions de l’exemple n’est pas suffisant. Il faut au minimum modifier ces fonctions, par exemple en ajoutant un paramètre ou en modifiant la forme de maison produite, etc.</li>
# </ol>
# </div>

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#     <h2 style="margin:0;"><a id="objectifsProjet"></a> 1. Objectifs du projet</h2>
# </div>
#
#
# - **Être capable de collaborer** sur un projet informatique.
#   - Pouvoir se répartir le travail, par exemple en identifiant les formes complexes à implémenter sous forme de fonctions Python, et qui peuvent être développées séparément.
# - **S'assurer de pouvoir continuer le programme** même si un·e camarade est absent·e durant un cours. Utiliser par exemple un dossier partagé sur le drive.
# - **Être capable de déboguer** un programme (par exemple : tester une fonction séparément, utiliser des commentaires pour identifier un problème).
# - **Pouvoir décomposer et structurer** un programme en sous-programmes implémentés par des fonctions.
#   - Avoir un processus de développement cohérent avec cette approche : décomposer le développement en étapes successives avec une validation pour chaque étape.
#   - Chaque forme doit être implémentée par une fonction, avec ou sans paramètres selon le besoin.
#     - Le curseur doit toujours revenir à sa position initiale et à son **orientation initiale**.
# - **Être capable de documenter** un programme avec des commentaires.
# - **Utiliser des boucles** pour factoriser le code, en particulier pour des formes qui se répètent.
#   - Utiliser une variable pour créer des variations dans les répétitions.
# - **Utiliser une entrée** (`input`) pour avoir un programme **interactif**.
#   - Au moins **une valeur numérique**.
# - **Être capable d’utiliser** les différentes fonctions du module Python `turtle` pour tracer des figures avec des épaisseurs, couleurs et formes différentes.
# - **Être capable de vectoriser** un dessin avec « un algorithme ».

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;"><a id="cahierDesCharges"></a> 2. Cahier des charges et évaluation</h2>
# </div>
#
# On veut réaliser un dessin respectant les critères suivants (voir exemples de projets réalisés les années précédentes). À la fin du projet, les critères suivants doivent être remplis :
# - Dessin original et harmonieux.
# - Au moins **trois formes** complexes différentes (étoile, maison, nuage, etc.), dont **une est répétée avec des variations** (par exemple : couleur, taille, forme, etc.).
# - Les formes utilisent **plusieurs couleurs** (traits et remplissages) et des **épaisseurs différentes**.
# - L’utilisateur·ice peut choisir **au moins 2 paramètres** du dessin (**1 choix multiple** et **une entrée libre**).

# %% [markdown]
# <div style="background:#FFFFFF;border-left:6px solid #1976D2;padding:14px;margin:16px 0;">
#   <div style="font-size:20px;font-weight:700;margin-bottom:10px;">
#     Idée de planning – déroulement du projet
#   </div>
#
#   <!-- En-tête -->
#   <div style="display:flex;font-weight:900;background:#BBDEFB;border:1px solid #90CAF9;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;">Rendu (semaine)</div>
#     <div style="flex:1;padding:10px;">À réaliser</div>
#   </div>
#
#   <!-- Ligne 1 (bleu) -->
#   <div style="display:flex;background:#E3F2FD;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>1</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Idée générale du dessin sur une feuille quadrillée.</div>
#       <div>• Création de l’arrière-plan (spécifier la couleur et la taille de la fenêtre).</div>
#       <div>• Création d’un dossier partagé sur le Drive entre vous et l'enseignant·e.</div>
#       <div>• Dépôt sur Moodle de la <strong>version 1</strong> :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div><code>projet_dessin_prenom1_prenom2_V1.py</code></div>
#         <div><code>idee_dessin_prenom1_prenom2_V1.png</code></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Ligne 2 (blanc) -->
#   <div style="display:flex;background:#FFFFFF;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>2</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• <strong>2 fonctions</strong> dessinant une forme complexe.</div>
#       <div>• Au moins <strong>une fonction</strong> avec <strong>au moins un paramètre</strong>.</div>
#       <div>• Commentaires : but de la fonction et rôle des paramètres.</div>
#       <div>• Introduction d’une <strong>boucle</strong> pour répéter automatiquement une forme.</div>
#       <div>• Dépôt sur Moodle de la <strong>version 2</strong> :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div><code>projet_dessin_prenom1_prenom2_V2.py</code></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Ligne 3 (bleu) -->
#   <div style="display:flex;background:#E3F2FD;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>3</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Variables au début du programme :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div>– largeur, hauteur, couleur de la fenêtre</div>
#         <div>– nombre de répétitions</div>
#       </div>
#       <div style="margin-top:6px;">• Variation dans la boucle (taille, épaisseur, etc.).</div>
#       <div>• Une question à l’utilisateur·ice pour choisir un paramètre.</div>
#       <div>• Dépôt sur Moodle de la <strong>version 3</strong> :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div><code>projet_dessin_prenom1_prenom2_V3.py</code></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Ligne 4 (blanc) -->
#   <div style="display:flex;background:#FFFFFF;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>4</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Poser une <strong>2ᵉ question</strong> permettant de saisir une <strong>valeur numérique</strong>.</div>
#       <div>• Dépôt sur Moodle de la <strong>version 4</strong> :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div><code>projet_dessin_prenom1_prenom2_V4.py</code></div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Ligne 5 (bleu) -->
#   <div style="display:flex;background:#E3F2FD;border:1px solid #90CAF9;border-top:none;">
#     <div style="width:90px;padding:10px;text-align:center;border-right:1px solid #90CAF9;"><strong>5</strong></div>
#     <div style="flex:1;padding:10px;">
#       <div>• Finaliser le dessin.</div>
#       <div>• Vérifier le cahier des charges complet.</div>
#       <div>• Dépôt sur Moodle de la <strong>version finale</strong> :</div>
#       <div style="margin-left:12px;margin-top:6px;">
#         <div><code>projet_dessin_prenom1_prenom2_Vfinal.py</code></div>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ### Éléments pris en compte dans l’évaluation
# #### 1) Structure du code
# - Le code est structuré de manière correcte et lisible:
#   - **1ʳᵉ partie** : import de la librairie `turtle` (et éventuellement de `random`).
#   - **2ᵉ partie** : définition des fonctions.
#   - **3ᵉ partie** : programme principal (production du dessin en appelant les fonctions définies dans la partie 2).
# - Des variables sont utilisées pour les différents paramètres du dessin et les noms des variables/fonctions décrivent correctement ce qu’elles représentent.
# - Des commentaires pertinents sont ajoutés afin de décrire le fonctionnement du code (un commentaire d’en-tête, des *docstrings* pour chaque fonction, et des commentaires pour rendre la lecture facile).
# - Chaque fonction est commentée en utilisant une *docstring* (voir l’exemple plus bas).
# - Le programme utilise les boucles à bon escient (le même code n’est pas répété plusieurs fois).
#
# #### 2) Résultat
# - Le programme fonctionne comme attendu (aucune erreur).
# - Originalité : le résultat se démarque des exemples donnés, ce qui indique une bonne compréhension des notions étudiées.
#
# #### 3) Modalités du TP
# - Chaque version hebdomadaire du TP a été rendue à temps sur Moodle.
# - Le fichier est correctement nommé du type : `projet_dessin_prenom1_prenom2_VX.py`.
# - Un dossier commun a été créer et partagé entre les membres du groupe

# %% [markdown]
# ## Grille d’évaluation (Proposition)
#
# > **Principe général**
# > Un programme qui fonctionne mais qui est mal structuré ne peut pas obtenir une bonne note.
# > La qualité du code est évaluée au même niveau que le rendu visuel.
#
#
# <div style="margin:24px 100px;">
#
# ### A. Organisation du travail et démarche (7 pts)
#
# <div style="float: right; clear: both;">
#
# | Critère | Attendu | Points |
# |---:|---:|---:|
# | Collaboration | Le travail est réparti entre les deux élèves (fonctions écrites par chacun) | / 1 |
# ||Le dossier partagé a été créé et partagé entre les membres du groupe et l’enseignant. | / 1 |
# | Démarche de projet | Les étapes demandées sont respectées (versions intermédiaires cohérentes) | / 5 |
#
# </div><div style="clear: both;"></div>
#
#
# ### B. Cahier des charges visuel (8 pts)
#
# <div style="float: right; clear: both;">
#
# | Critère | Attendu | Points |
# |---:|---:|---:|
# | Originalité | Dessin original, non copié, distinct des exemples vus | / 2 |
# | Dimension | Les dimensions de la fenêtre et la couleur de l’arrière-plan sont spécifiées au démarrage avec des variables. | / 1 |
# | Complexité | Au moins **3 formes complexes différentes** | / 3 |
# | Variété graphique | Couleurs, remplissages et épaisseurs variées | / 2 |
#
# </div><div style="clear: both;"></div>
#
#
# ### C. Décomposition et usage des fonctions (10 pts)
#
# <div style="float: right; clear: both;">
#
# | Critère | Attendu | Points |
# |---:|---:|---:|
# | Fonctions dédiées | Chaque élément visuel important correspond à une fonction | / 3 |
# | Fonctions avec paramètres | Au moins **2 fonctions avec paramètres pertinents** | / 3 |
# | Fonction appelant une autre fonction | Présence d’au moins **1 fonction** qui appelle une autre fonction créée dans le code | / 1 |
# | Fonctions propres | Chaque fonction ramène la tortue à sa position **et orientation initiales** | / 3 |
#
# </div><div style="clear: both;"></div>
#
# ### D. Boucles et factorisation du code (6 pts)
#
# <div style="float: right; clear: both;">
#
# | Critère | Attendu | Points |
# |---:|---:|---:|
# | Usage des boucles | Les boucles `for` évitent les répétitions de code | / 3 |
# | Variation | Une forme est répétée avec **au moins un paramètre qui varie** | / 3 |
#
# </div><div style="clear: both;"></div>
#
# ### E. Interactivité et logique conditionnelle (6 pts)
#
# <div style="float: right; clear: both;">
#
# | Critère | Attendu | Points |
# |---:|---:|---:|
# | Interaction | Le programme pose **au moins deux questions** à l’utilisateur·ice | / 2 |
# | Type des entrées | Une entrée libre et une **valeur numérique** | / 2 |
# | Conditions | Utilisation correcte de `if / elif / else` | / 2 |
#
# </div><div style="clear: both;"></div>
#
# ### F. Qualité du code et documentation (4 pts)
#
# <div style="float: right; clear: both;">
#
# | Critère | Attendu | Points |
# |---:|---:|---:|
# | Structure du programme | Imports / fonctions / programme principal bien séparés | / 1 |
# | Nommage | Noms des variables et fonctions clairs et explicites | / 1 |
# | Commentaire d’en-tête | Auteur·ices, date, version et description présents | / 1 |
# | Docstrings | Chaque fonction est documentée par une *docstring* | / 1 |
#
# </div><div style="clear: both;"></div>
#
# ### G. Fonctionnement et rendu final (2 pts)
#
# <div style="float: right; clear: both;">
#
# | Critère | Attendu | Points |
# |---:|---:|---:|
# | Exécution | Programme exécutable sans erreur | / 1 |
# | Rendu final | Dessin complet et conforme aux consignes | / 1 |
#
# </div><div style="clear: both;"></div>
#
# ### Total
#
# <div style="float: right; clear: both;">
#
# | Total | Points |
# |---:|---:|
# | Total obtenu | **/ 43** |
#
# **Calcul de la note (barème fédéral)**
# **Note = (points / 43) × 5 + 1**
# </div>

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;"><a id="avancerSeul"></a> 3. Comment avancer en dehors des cours</h2>
# </div>
#
# Si vous avez suivi les consignes, après la première semaine, votre programme ( fichier `projet_dessin_prenom1_prenom2_VX.py`) a été déposé dans un dossier partagé sur le [Google Drive EEL](https://drive.google.com/a/eduge.ch). Pour avancer en dehors des cours, il vous suffit de télécharger sur votre ordinateur la dernière version du porogramme et d'ouvrir le fichier avec Thonny.
#
# !!! warning Ne pas oublier de redéposé le programme sur le Drive après les modifications
# Après avoir effectué des modifications à votre programme il ne faudra pas oublier de téléverser le fichier dans  votre dossier partagé sur le [Google Drive EEL](https://drive.google.com/a/eduge.ch).
#
# !!!
#
#
# Il y a plusieurs possibilités pour avancer :
# - Utiliser un ordinateur de la bibliothèque.
# - Aller à l'assistance pédagogique le lundi entre 11h50 et 13h0 en salle B115.
# - Utiliser votre propore ordinateur après avoir téléchargé et installé **Thonny** en utilisant un des liens suivants.
#     - Pour Windows : https://github.com/thonny/thonny/releases/download/v4.1.7/thonny-4.1.7.exe
#     - Pour MacOS : https://github.com/thonny/thonny/releases/download/v4.1.7/thonny-4.1.7.pkg

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;"><a id="nePasFaire"></a>4. Ce qu'il ne faut pas faire !</h2>
# </div>

# %% [markdown]
# ## Pourquoi il ne faut pas réaliser le projet comme l'exemple suivant:
#
# Le programme ci-dessous **fonctionne visuellement**, mais **ne respecte pas les objectifs du projet**.
# L’objectif de ce travail pratique n’est pas seulement de dessiner, mais d’écrire un **code structuré, lisible et de qualité**.
#
# Voici les principales raisons pour lesquelles cette manière de programmer n’est **pas acceptable** dans le cadre de ce projet.

# %% [markdown]
# <details>
#   <summary style="cursor:pointer; font-weight:bold; color:red;">
#     ▶ Exemple de ce qu'il ne faut pas faire : Cliquer sur ce texte pour voir le code.
#   </summary>
#
#   <pre>
# from turtle import *
# speed(0)
# Screen().bgcolor("skyblue")
# backward(320)
# fillcolor("burlywood")
# begin_fill()
# forward(900)
# right(90)
# forward (500)
# right(90)
# end_fill()
# fillcolor("burlywood")
# begin_fill()
# forward(900)
# right(90)
# forward (500)
# right(90)
# end_fill()
# forward(30)
# fillcolor("bisque4")
# begin_fill()
# forward(200)
# left(90)
# forward(95)
# left(90)
# end_fill()
# fillcolor("bisque4")
# begin_fill()
# forward(200)
# left(90)
# forward(95)
# left(90)
# end_fill()
# fillcolor("brown4")
# begin_fill()
# left(90)
# forward(95)
# right(25)
# forward(40)
# right(65)
# forward(165)
# right(65)
# forward(40)
# right(115)
# forward(200)
# end_fill()
# right(115)
# forward(40)
# right(65)
# forward(20)
# left(90)
# fillcolor("cornsilk")
# begin_fill()
# forward(20)
# left(90)
# forward(5)
# left(90)
# end_fill()
# fillcolor("cornsilk")
# begin_fill()
# forward(20)
# left(90)
# forward(5)
# left(90)
# end_fill()
# penup()
# left(180)
# forward(130)
# left(90)
# forward(127)
# left(90)
# pendown()
# fillcolor("azure3")
# begin_fill()
# forward(40)
# left(90)
# forward(20)
# left(90)
# end_fill()
# fillcolor("azure3")
# begin_fill()
# forward(40)
# left(90)
# forward(20)
# left(90)
# end_fill()
# penup()
# forward(20)
# left(90)
# forward(18)
# pendown()
# fillcolor("black")
# begin_fill()
# circle(1)
# end_fill()
# forward(2)
# left(90)
# forward(20)
# penup()
# right(90)
# forward(127)
# right(90)
# pendown()
# forward(40)
# right(90)
# forward(70)
# right(90)
# forward(40)
# left(180)
# forward(4)
# left(90)
# forward(70)
# right(90)
# forward(4)
# right(90)
# forward(70)
# left(90)
# forward(4)
# left(90)
# forward(70)
# right(90)
# forward(4)
# right(90)
# forward(70)
# left(90)
# penup()
# forward(40)
# left(90)
# forward(60)
# left(180)
# pendown()
# fillcolor("LightBlue2")
# begin_fill()
# forward(20)
# right(90)
# forward(20)
# right(90)
# end_fill()
# fillcolor("LightBlue2")
# begin_fill()
# forward(20)
# right(90)
# forward(20)
# right(90)
# end_fill()
# forward(10)
# right(90)
# forward(20)
# left(90)
# forward(10)
# left(90)
# forward(10)
# left(90)
# forward(20)
# right(90)
# forward(10)
# right(90)
# penup()
# forward(80)
# pendown()
# fillcolor("gold")
# begin_fill()
# forward(80)
# right(90)
# forward(26)
# right(90)
# end_fill()
# fillcolor("gold")
# begin_fill()
# forward(80)
# right(90)
# forward(26)
# right(90)
# end_fill()
# right(90)
# forward(13)
# left(90)
# forward(80)
# left(90)
# forward(13)
# left(90)
# forward(40)
# left(90)
# forward(26)
# penup()
# left(90)
# forward(300)
# left(90)
# forward(160)
# fillcolor("gold")
# begin_fill()
# circle(60)
# end_fill()
# penup()
# left(180)
# forward(214)
# left(90)
# forward(100)
# left(90)
# pendown()
# forward(40)
# width(2)
# forward(26)
# left(180)
# forward(13)
# right(90)
# forward(12)
# penup()
# forward(120)
# left(90)
# forward(53)
# left(200)
# pendown()
# forward(14)
# left(130)
# forward(17)
# left(180)
# forward(17)
# left(24)
# forward(20)
# left(90)
# forward(16)
# left(180)
# forward(16)
# left(140)
# forward(16)
# left(180)
# forward(16)
# circle(4)
# penup()
# left(240)
# forward(140)
# right(105)
# pendown()
# width(1)
# forward(40)
# width(2)
# forward(26)
# left(180)
# forward(13)
# left(90)
# forward(12)
# penup()
# forward(40)
# left(90)
# forward(20)
# fillcolor("OrangeRed2")
# begin_fill()
# circle(4)
# end_fill()
# penup()
# forward(27000000)
# done()
# </pre>
# </details>

# %% [markdown]
# ### 1️⃣ Il n'y a pas de commentaire d'en-tête
# Le projet exige un commentaire d’en-tête contenant :
# - le ou les auteur·ices,
# - la date,
# - une description du programme.
#
# **Ce que l’on observe :**
# - aucune information sur l’auteur ;
# - aucune indication sur l’objectif du programme.
#
# *Sans en-tête, le travail est incomplet.*
#
# ### 2️⃣Le code n’est pas structuré
#
# **Ce que l’on observe :**
# - Le programme est écrit sous forme d’un **bloc unique**, ligne après ligne.
# - Il n’y a aucune séparation entre :
#   - la préparation du programme,
#   - le dessin des différentes formes,
#   - le programme principal.
#
# **Pourquoi c’est un problème :**
# - Le projet demande explicitement une **structure claire du programme**.
# - Un code non structuré est :
#   - difficile à lire,
#   - difficile à corriger,
#   - difficile à modifier.
#
# *Un programme de qualité n’est pas une simple suite d’instructions.*
#
#
#
# ### 3️⃣Aucune fonction n’est utilisée
#
# **Ce que l’on observe :**
# - Il n’y a **aucune fonction** (`def`) dans le programme.
# - Toutes les formes sont dessinées directement dans le programme principal.
#
# **Pourquoi c’est un problème :**
# - L’énoncé impose :
#   - l’utilisation de **fonctions avec et sans paramètres** ;
#   - une fonction par élément visuel important.
# - Sans fonctions :
#   - le code n’est pas réutilisable,
#   - il est impossible de tester une partie séparément,
#   - le travail en groupe devient très difficile.
#
# *Une forme complexe doit être définie dans une fonction.*
#
# ### 4️⃣ Beaucoup de répétitions inutiles
#
# **Ce que l’on observe :**
# - De nombreuses séquences de code identiques sont répétées. L'usage d'une boucle `for` serait utile.
# - Exemple :
# ```python
# fillcolor("burlywood")
# begin_fill()
# forward(500)
# right(90)
# forward(500)
# right(90)
# end_fill()
# ```
#
# ### 5️⃣ Aucune interaction avec l’utilisateur
#
# Le cahier des charges impose :
# - au moins deux questions à l’utilisateur ;
# - une entrée libre et une valeur numérique ;
# - l’utilisation de if / elif / else.
#
# **Ce que l’on observe :**
# - aucun `input()` ;
# - aucune condition ;
# - l’utilisateur-trice n’a aucun contrôle sur le dessin.
#
# *Le programme ne peut donc pas être qualifié d’interactif.*
#
# ### 6️⃣ Il n’y a aucun commentaire explicatif
# Un bon programme doit contenir :
# - des commentaires pour expliquer les étapes importantes ;
# - des docstrings pour expliquer les fonctions.
#
# **Ce que l’on observe :**
# - aucun commentaire ;
# - personne ne peut comprendre ce que représente chaque partie du dessin ;
# - même l’auteur aura de la peine à s’y retrouver plus tard.
#
# *Un code non commenté est considéré comme non terminé.*

# %% [markdown]
# <div style="
#     background-color:#E3F2FD;
#     border-left:6px solid #1976D2;
#     padding:12px;
#     margin:16px 0;
# ">
#   <h2 style="margin:0;"><a id="planning"></a>5. Planning et tâches à effectuer</h2>
# </div>

# %% [markdown]
# ## <a id="tachesRendu1"></a> 🟥 Tâches premier rendu
#
# ### i. Utiliser Thonny pour écrire des programmes Python
#
# Regarder la vidéo:
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/d6KfCZbtnLc?si=sFexq7qEKCGxtbYP" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
#
#
# ### ii. Structure du fichier `.py` et commentaires obligatoires
#
#
# Votre programme doit commencer avec un commentaire d’en-tête, puis être structuré par des commentaires qui séparent le programme en 3 parties comme ci-dessous :
#
# ```python
# ''' Auteur(s) : votre(vos) nom(s)
# Contact(s) : votre(vos) courriel(s)
# License : "CC-BY-NC-SA"
# Date : la date du jour
# Version : 1.0
# Description : La description de votre programme
# '''
# # PARTIE 1: IMPORTATION ET CONSTANTES
# from turtle import *
#
#
# # PARTIE 2: DÉFINITIONS DE FONCTIONS
# def ...
#
#
#
# # PARTIE 3: PROGRAMME PRINCIPAL (arrière-plan, appel des fonctions, déplacements)
#
#
# ```
#
#
# ??? info C'est quoi cette License "CC-BY-NC-SA"
# La ligne `License` renseigne sur la manière dont vous souhaitez partager et protéger votre travail. Par exemple, pour la licence `CC-BY-NC-SA` on a
#
# - **CC** (*Creative Commons*): Le nom de la licence .
# - **BY** (Attribution) : Il est possible d'utiliser ce programme sans droit d'auteur (CopyLeft) mais il faut citer le(s) auteur(s) du programme.
# - **NC** (Non-Commercial) : Il est interdit de gagner de l'argent avec ce programme.
# - **SA** (Share Alike) : Il est possible de modifier le programme mais la nouvelle version doit garder cette même licence.
# ???
#
#
# ### iii. Spécifier la taille de la fenêtre et la couleur de fond
# Pour spécifier la taille de la fenêtre et la couleur de fond, ajouter les instructions suivantes **au début** de la partie 3 :
#
# ```python
# setup(300, 400)  # fixe la taille de la fenêtre à 300 pixels x 400 pixels
# bgcolor("cyan")   # fixe la couleur de l’arrière-plan
#
# ```
#
# ??? info Couleurs et taille de la fenêtre
# - La résolution la plus courante sur un écran de PC moderne est de ***1920x1080 pixels***.
# - Vous trouverez une [palette complète de couleur ici](https://cs111.wellesley.edu/reference/colors).
# - On peut aussi directement donner la couleur en donnant le code RGB à travers une chaîne de caractères où les valeurs sont données en hexadécimale. Par exemple, `bgcolor("#00FF00")` permet de choisir le vert comme couleur d'arrière-plan. Vous pouvez utiliser un [selecteur de couleur](https://rgbcolorpicker.com/) pour touver le code associé à une couleur.
# - Finalement, en écrivant `colormode(255)` au début de notre programme, on peut ensuite choisir une couleur RGB avec `color(r, g, b)`, avec les 3 paramètres  `r, g, b` compris entre 0 et 255.
# ???
#
# ### iv. Partager son travail en utilisant le google Drive
#
#
# **À faire:**
# - Créer et partager un dossier sur le [Google Drive EEL](https://drive.google.com/a/eduge.ch).
# - Téléverser votre programme (fichier `projet_dessin_prenom1_prenom2_V1.py`) dans le dossier.
# - Téléverser l'image de votre projet de dessin (fichier `idee_dessin_prenom1_prenom2_V1.png`) dans le dossier.

# %% [markdown]
# ## <a id="tachesRendu2"></a> 🟥 Tâches deuxième rendu
#
# ### i. écrire et tester des fonctions
# **À faire:**
#
#    - Ajouter au moins deux fonctions dont au moins une des deux possède un paramètre qui permettent de tracer des figures complexes.
#    - Chacun des membres du groupe doit avoir écrit une des fonctions.
#    - Tester les fonctions et l'intégrer pour votre dessin.
#
# !!! tip Astuce 1 : Comment collaborer
#
# Pour collaborer, utiliser des fichiers temporaire que vous téléversé dans votre  Drive partagé. Par exemple, dans votre Drive partagé vous avez les fichiers suivants:
# - `projet_dessin_prenom1_prenom2_V1.py` : la version 1 de votre projet
# - `projet_dessin_prenom1_prenom2_V2.py` : la version 2 de votre projet
# - etc,
#
# - `idee_dessin_prenom1_prenom2_V1.png` : l'image de votre projet
#
# - `fonctions_prenom1_tmp.py` : Les fonctions qui ont été implémentées par le premier élèves et qui doivent encore être ajoutées au projet (fichier `projet_dessin_prenom1_prenom2_Vx.py`.
# - fonctions_prenom2.py: Même chose pour les fonctions du deuxième élève.
#
# Le but est de développer et tester les fonctions dans un fichier séparé et de les inclure au fur et à mesure au projet.
# !!!
#
# !!! tip Astuce 2 : définir sa prore fonction `deplacer`
# Il est souvent utile d'utiliser  `goto(x,y)` avec `penup()` et `pendown()`. On peut définir sa propre fonction réalisant cette tâche, par exemple:
#
# ```python
# def deplacer(x,y):
#     penup()
#     goto(x,y)
#     pendown()
# ```
# !!!
#
# !!! tip Astuce 3 : Revenir facilement au point de départ
#
# Après qu'une fonction ait tracé une figure, il faudrait que la *tortue* revienne au point de départ avec l'orientation initiale. Pour ce faire, on peut stoquer dans des variables la position et l'orientation  initiale:
#
# ```python
# def ma_figure():
#     pos_x = xcor() # coordonnée x au départ
#     pos_y = ycor() # coordonnée y au départ
#     orientation = heading() # l'orientation au départ
#
#     # code de la figure...
#
#     deplacer(pos_x, pos_y)  # se remettre à la position de départ
#     setheading(orientation) # avec la même orientation
# ```
# !!!
#
# #### Exemple
#
# Testons le programme ci-dessous

# %%
from turtle import *

def arbre(hauteur_tronc, couleur_tronc, couleur_feuilles):
    pendown()
    left(90)
    width(hauteur_tronc/6)                # largeur du tronc
    pencolor(couleur_tronc)
    forward(hauteur_tronc)
    dot(hauteur_tronc, couleur_feuilles)  # feuillage simulé par un gros point
    penup()


# Programme principal
arbre(100, 'brown', 'lime')     # dessin du 1er arbre
forward(70)
arbre(90, 'brown', 'green')     # dessin du 2e arbre
forward(70)
arbre(60, 'brown', 'DarkOliveGreen')     # dessin du 3e arbre

done()

# %% [markdown]
# Comme après avoir dessiné l'arbre, la *tortue* ne revient pas à la position et à l'orientation initiale, il est difficile de dessiner plusieurs arbres les uns après les autres. En faisant, le modification de l'astuce 2 on a

# %%
from turtle import *

def deplacer(x,y):
    penup()
    goto(x,y)
    pendown()

def arbre(hauteur_tronc, couleur_tronc, couleur_feuilles):
    pos_x = xcor() # coordonnée x au départ
    pos_y = ycor() # coordonnée y au départ
    orientation = heading() # l'orientation au départ
    
    pendown()
    left(90)
    width(hauteur_tronc/6)                # largeur du tronc
    pencolor(couleur_tronc)
    forward(hauteur_tronc)
    dot(hauteur_tronc, couleur_feuilles)  # feuillage simulé par un gros point
    penup()
    
    deplacer(pos_x, pos_y)  # se remettre à la position de départ
    setheading(orientation) # avec la même orientation
    
    

# Programme principal
arbre(100, 'brown', 'lime')     # dessin du 1er arbre
forward(70)
arbre(90, 'brown', 'green')     # dessin du 2e arbre
forward(70)
arbre(60, 'brown', 'DarkOliveGreen')     # dessin du 3e arbre

done()

# %% [markdown]
# #### Exemple 2
#
# On peut utiliser la position de départ pour dessiner une figure avec `goto(x,y)` en utilisant les coordonnées relatives au point de départ. Par exemple, la fonction `coeur()` permettra de dessiner des coeurs avec `goto(x,y)` là où la tortue se trouve

# %%
from turtle import *

def deplacer(x,y):
    penup()
    goto(x,y)
    pendown()

def coeur():
    pos_x = xcor() # coordonnée x au départ
    pos_y = ycor() # coordonnée y au départ
    
    # dessin do coeur
    goto(pos_x + 100, pos_y + 100)
    goto(pos_x + 100, pos_y + 150)
    goto(pos_x + 50 , pos_y + 200)
    goto(pos_x + 0  , pos_y + 150)
    goto(pos_x - 50 , pos_y + 200)
    goto(pos_x - 100, pos_y + 150)
    goto(pos_x - 100, pos_y + 100)
    
    goto(pos_x,pos_y)
    
coeur()
deplacer(-200,-200)
coeur()

done()

# %% [markdown]
# ### ii. Ajouter des Docstring pour chaque fonction (obligatoire)
# Chaque fois qu’une fonction est définie, il est demandé d’ajouter un commentaire de type **docstring** (c’est un commentaire encadré par des triple apostrophes `''' ... '''`) qui indique :
# - ce que fait la fonction,
# - l'auteur de la fonction,
# - si elle a des paramètres,
# - quels sont leurs types,
# - ce que représentent ces paramètres,
# - et un exemple d'utilisation
#
# **Exemple :**
#
# ```python
# def arbre(h, c1, c2):
#     ''' dessine un arbre
#     Auteur : Mathieu Schiess
#     param(s) :
#     h (int) : la hauteur du tronc de l'arbre
#     c1 (str) : la couleur (turtle) du tronc
#     c2 (str) : la couleur (turtle) du feuillage
#
#     Exemple: arbre(100, "chocolate", "green")
#     '''
#     pos_x = xcor() # coordonnée x au départ
#     pos_y = ycor() # coordonnée y au départ
#     orientation = heading() # l'orientation au départ
#
#     pendown()
#     left(90)
#     width(h/6)                # largeur du tronc
#     pencolor(c1)
#     forward(h)
#     dot(h, c2)  # feuillage simulé par un gros point
#     penup()
#
#     deplacer(pos_x, pos_y)  # se remettre à la position de départ
#     setheading(orientation) # avec la même orientation
# ```
#
# ### iii. Avoir un forme qui se répète dans une boucle
# Vous devez avoir une forme qui se répète dans une boucle. Par exemple, une forêt qui est dessiner en faisant des appels à une fonction arbre.
#
# ### iv.  Dépôt sur Moodle de la version 2 :
# **À faire:**
# - Téléverser l'image de votre projet de dessin (fichier `idee_dessin_prenom1_prenom2_V2.png`) dans le dossier.

# %% [markdown]
# ## <a id="tachesRendu3"></a> 🟥 Tâches troisième rendu
#
# ### i. Variables au début du programme :
# Pour modifier plus facilement notre programme, on veut **stocker nos constantes dans des variables** dans la partie 1. Par exemple :
#
#
# ```python
# LARGEUR = 300
# HAUTEUR = 400
# COULEUR_FOND = "cyan"
#
# setup(LARGEUR, HAUTEUR)  # fixe la taille de la fenêtre aux nombres de pixels fixés par les variables
# bgcolor(COULEUR_FOND)   # fixe la couleur de l’arrière-plan à la valeur entrée dans la variable couleur_fond
# ```
#
# Cela nous permet d'avoir un programme plus clair, mais également d'utiliser ces valeurs à plusieurs endroits du programme, par exemple pour se rendre en haut à droite du dessins :
#
#
# ```python
# goto(LARGEUR // 2, HAUTEUR // 2)
# ```
# !!! info Les constantes
# - Les constantes sont des variables dont la valeur est fixe tout au long du programme. On donne un valeur au début du programme qui ne changera jamais.
# - En python, il est d'usage de nommer les constantes en utilisement seulement des MAJUSCULES.
# !!!
#
# ### ii. Variation dans la boucle (taille, épaisseur, etc.).
# Maintenant que vos 2 fonctions sont définies, placez vos objets sur l'écran, dont un qui est répété dans une boucle avec une variation. Par exemple, des arbres de plus en plus grands / épais / etc., ou même des objets de taille aléatoire.
# ### iii.  Une question à l’utilisateur·ice pour choisir un paramètre.
# Finalement, on va demander avec `input` à l’utilisateur·ice de choisir un paramètre différent à chaque dessin.
#
# Ca peut être le nombre d'objets, la taille, la couleur, etc.
#
# ### iv.  Dépôt sur Moodle de la version 3 :
#
# **À faire:**
# - Téléverser l'image de votre projet de dessin (fichier `idee_dessin_prenom1_prenom2_V2.png`) dans le dossier.

# %% [markdown]
# ## <a id="tachesRendu4"></a> 🟥 Tâches quatrième rendu
#
# ### i. Poser une 2ᵉ question permettant de saisir une valeur numérique.
#
#
# ### ii.  Dépôt sur Moodle de la version 3 :
#
# **À faire:**
# - Téléverser l'image de votre projet de dessin (fichier `idee_dessin_prenom1_prenom2_V4.png`) dans le dossier.

# %% [markdown]
# ## <a id="tachesRendu5"></a> 🟥 Tâches cinquième rendu
#
# ### i. Finaliser le dessin.
# ### ii. Vérifier le cahier des charges complet.
# ### iii.  Dépôt sur Moodle de la version finale :
#
# **À faire:**
# - Téléverser l'image de votre projet de dessin (fichier `projet_dessin_prenom1_prenom2_Vfinal.png`) dans le dossier.

# %% [markdown]
# ---
#
# #### Remarque générale
#
# Ce document a été élaboré par les enseignant du collège Sismondi à Genève. Il est sous license Creative Commons [BY-NC-SA](https://creativecommons.org/licenses/?lang=fr)
# ![Licence Creative Commons](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
