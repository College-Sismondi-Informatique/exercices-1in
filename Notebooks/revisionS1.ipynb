# %% [markdown]
# <div class = "alert  alert-danger">
#
# Attention: **veillez à bien sauvegarder votre travail** dans le bon dossier du disque réseau (dossier document) avec le bon nom (et l'extension *.ipynb*), **sinon toutes les modifications seront perdues!**
#
# Pour reprendre votre travail, il suffit d'ouvrir le fichier .ipynb en cliquant sur *Fichier ouvrir*
# </div>
#
#
# # Exercices de révision pour la première évaluation de programmation

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 0 </h3>
#
# Ecrire un programme qui affiche `Dans une images codé en 24 bit il y a 2**24 couleurs` où à la place de `2**24` il y a le résultat du calcul (c'est-à-dire le résultat de $2^{24}$) .

# %%
 # votre programme

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 1 </h3>
#
# 1. Testez le programme suivant:

# %%
from turtle import *

for _ in range(3):
    right(120)
    forward(100)
    for _ in range(5):
        forward(10)
        backward(10)
        left(72)
done()

# %% [markdown]
# 2. Réécrire le programme en définissant et en utilisant une fonction nommée `étoile` qui permet des dessiner une des étoiles qui appartait sur chacun des sommets de la figure.

# %%
from turtle import *

def # a compléter 

# a compléter 
done()

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 2 (S1.7) </h3>
# Écrire un programme qui définit une fonction `carre` et une fonction `triangle` et utilise ces fonctions pour dessiner 5 fois le carré et le triangle comme sur la figure ci-dessous. Le code ne devrait pas dépasser 20 lignes (sans compter les lignes vides et les lignes de commentaires).
#
# ![Suite de triangle et de carré](https://githepia.hesge.ch/info_sismondi/exercices-1ere/-/raw/main/Notebooks/imgs_chap3/ex_triangle_carre.svg)

# %%
from turtle import *


# Définition des fonctions

def carré(): 
    # à comnpléter
    
    
    
def triangle(): 
    # à comnpléter
    
    
# Programme principal (utilisation des fonction)





done()

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 3 (S1.9) </h3>
#
# Dans une évaluation d'infomatique il est demandé d'écrire un programme qui permet de dessiner la figure suivante:
# ![Image de triangle dans un triangle](https://githepia.hesge.ch/info_sismondi/exercices-1ere/-/raw/main/Notebooks/imgs_chap3/sierpinski.png)
#
# Loan a regardé l'écran de Lisa et recopié la proposition suivante
# ```python
# from turtle import *
#
# for _ in range(3):
#     for _ in range(3):
#         forward(50)
#         left(120)
#     forward(-50)
#     right(120)
#
# done()
# ```
# D'après ce qu'il voit de l'écran de Léa, le programme devrait produire la bonne figure. Malheureusement, il a fait des erreurs de copies.
#
# Tester le programme de Loan et aider le afin que le programme dessine la bonne figure.

# %%
# le programme a tester et modifier
from turtle import *

for _ in range(3):
    for _ in range(3):
        forward(50)
        left(120)
    forward(-50)
    right(120)

done()

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 4 (S1.11) </h3>
#
# Écrire un programme qui permet de produire le résultat ci-dessous dans la console à l’aide de trois boucles for imbriquées. On prendra garde à respecter les sauts de ligne.
#
# ```
# matin
# midi soir soir soir
# midi soir soir soir
#
# matin
# midi soir soir soir
# midi soir soir soir
# ```

# %%
# votre programme

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 5 (S1.12)</h3>
#
# Tester le programme ci-dessous
#
# ```python
# from turtle import *
#
# for _ in range(3):
#     right(120)
#     forward(100)
#     for _ in range(4):
#         forward(10)
#         backward(10)
#         left(90)
#     goto(0,0)
# done()
#
# ```
# puis modifier le afin qu'il dessine la figure suivante, une fleur de pissenlit très simplifiée.
#
# ![Image de fleur simplidiée](https://githepia.hesge.ch/info_sismondi/exercices-1ere/-/raw/main/Notebooks/imgs_chap3/fleur_etoile.png)
#
# Le point indique l’origine du repère. La tige a une longueur de 150, les branches ont une longueur de 50 et la longueur des “graines” est de 10.

# %%
# le programme a tester et modifier
from turtle import *

for _ in range(3):
    right(120)
    forward(100)
    for _ in range(4):
        forward(10)
        backward(10)
        left(90)
    goto(0,0)
done()

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 6 (S1.13) </h3>
#
# Écrire un programme qui définit une fonction `carre` et une fonction `quadrillage` (qui dessine 4 carrés en utilisant  `carre`) et utilise ces fonctions dans une boucle `for` afin de dessiner la figure suivante:
#
# ![Image de triple quadrillage](https://githepia.hesge.ch/info_sismondi/exercices-1ere/-/raw/main/Notebooks/imgs_chap3/triple_carre.png)
#
# On suppose que les petits carrés font 30x30.

# %%
# votre programme
