# %% [markdown]
# # Compilation des évaluations

# %% [markdown]
# ## Tableau récapitulatif de l'avancement
#
# | Élève | Ex 1 | Ex 2 | Ex 3 | Ex 4 | Ex 5 | Ex 6 | Ex 7 | Ex 8 |
# |-------|-------|-------|-------|-------|-------|-------|-------|-------|
# | BERNARD LUC | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ❌ | ✅ |
# | DUPONT JEAN | ✅ | ✅ | ✅ | ❌ | ✅ | ✅ | ❌ | ❌ |
# | DURAND MARC | ✅ | ✅ | ✅ | ❌ | ❌ | ✅ | ❌ | ❌ |
# | GARCIA JULIE | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ❌ | ✅ |
# | LAURENT JULES | ✅ | ✅ | ✅ | ❌ | ✅ | ✅ | ❌ | ✅ |
# | LEFEBVRE ANNE | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ❌ | ✅ |
# | LEROY CLAIRE | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ❌ | ❌ |
# | MARTIN MARIE | ✅ | ✅ | ✅ | ❌ | ✅ | ✅ | ❌ | ✅ |
# | MICHEL LOUIS | ✅ | ✅ | ✅ | ❌ | ❌ | ✅ | ❌ | ✅ |
# | MOREAU PAUL | ✅ | ✅ | ✅ | ❌ | ✅ | ✅ | ❌ | ❌ |
# | PETIT SOPHIE | ✅ | ✅ | ✅ | ❌ | ✅ | ✅ | ❌ | ✅ |
# | RICHARD ALICE | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ❌ | ✅ |
# | ROBERT PIERRE | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ❌ | ✅ |
# | ROUX THOMAS | ✅ | ✅ | ✅ | ❌ | ❌ | ✅ | ❌ | ✅ |
# | SIMON EMMA | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ❌ | ✅ |

# %% [markdown]
# ---
#
# ## Exercice 1
#
# **Énoncé**
#
# ## A) Vision par ordinateur
#
# Pour la partie vision, nous allons utiliser une image nommée `maxresdefault.jpg` issue de la chaîne youtube [@PankajMali](https://www.youtube.com/@PankajMali) dans le but final de mesurer la largeur de la tête du youtubeur.
#
# !!! note Exercice 1 (8 pts)
#
# * Chargez et afficher l'**image originale** avec la librairie openCV
# * Affichez une version en **niveaux de gris**
# * Détectez les **contours** avec le filtre de canny puis affichez-les, après vous être assuré·e de **supprimer le bruit** (nettoyer l'image pour éviter d'avoir trop de "faux contours").
#
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")

cv2.imshow('Original photo', image)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)
edges = cv2.Canny(gray,100,200)
median = cv2.medianBlur(image, 5)  
edges = cv2.Canny(median,100,200)
cv2.imshow('Gray image', edges)

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)

#canny= cv2.Canny(gray,100,200)
#cv2.imshow('Paysage', canny)

median = cv2.medianBlur(image, 5)  
median1 = cv2.Canny(median,100,200)
cv2.imshow('Paysage', median1)

# %% [markdown]
# ### Réponse de DURAND MARC

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")
cv2.imshow('Paysage', image)
#print(image)

b,g,r = cv2.split(image)
gray_computed = (b/3+g/3+r/3)
cv2.imshow('computed Gray image', gray_computed)
#print(gray_computed)


gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)
#print(gray)

edges = cv2.Canny(gray,100,200)
cv2.imshow('Paysage', edges)

median = cv2.medianBlur(image, 5)  
edges = cv2.Canny(median,100,200)
cv2.imshow('Paysage', edges)

# On observe que la valeur de gris n'est pas vraiment donnée par la moyenne des valeurs R, G et B. 
# Un poids est appliquée pour mieux correspondre à la vision humaine : 0.299⋅R+0.587⋅G+0.114⋅B

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %%
import cv2
image = cv2.imread("maxresdefault.jpg")
cv2.imshow('Beaugosse', image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Gray Beaugosse', gray)

median = cv2.medianBlur(image, 9)  
cv2.imshow('Beaugosse flouté', median)
cv2.imshow('Beaugosse contrasté', 2*(image-0.5*median))
edges = cv2.Canny(median,90,210)
cv2.imshow('Beaugosse', edges)

# %% [markdown]
# ### Réponse de LAURENT JULES

# %%
import cv2

img = cv2.imread("maxresdefault.jpg")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edge = cv2.Canny(gray, 100, 200)
blur = cv2.GaussianBlur(gray,(5,5), 0)

cv2.imshow("Image", img)
cv2.waitKey
cv2.destroyAllWindows

cv2.imshow("Image", gray)
cv2.waitKey
cv2.destroyAllWindows

cv2.imshow("Image", blur)
cv2.waitKey
cv2.destroyAllWindows


cv2.imshow("Image", edge)
cv2.waitKey
cv2.destroyAllWindows

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %%
import numpy as np
import cv2

image = cv2.imread("maxresdefault.jpg")
cv2.imshow("Maxresdefault", image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)

median = cv2.medianBlur(image, 7)  
cv2.imshow('Paysage flouté', median)

edges = cv2.Canny(median,100,200)
cv2.imshow('Paysage', edges)

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %%
import cv2 

image_originale = cv2.imread("maxresdefault.jpg")

cv2.imshow('image originale', image_originale)

gray = cv2.cvtColor(image_originale, cv2.COLOR_BGR2GRAY)

cv2.imshow('Gray image', gray)

median = cv2.medianBlur(image_originale, 5)  
edges = cv2.Canny(median,100,200)

cv2.imshow('image_originale', edges)

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")
cv2.imshow('Paysage', image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)

median = cv2.medianBlur(image, 7)  
cv2.imshow('Paysage flouté', median)

#edges = cv2.Canny(gray,100,200)
#cv2.imshow('Paysage', edges)

median = cv2.medianBlur(image, 5)  
edges = cv2.Canny(median,100,200)
cv2.imshow('Paysage', edges)

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %%
import cv2
image = cv2.imread("maxresdefault.jpg")
cv2.imshow('maxresdefault', image)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('maxresdefault_gray', gray)

edges = cv2.Canny(gray,100,200)
cv2.imshow('maxresdefault', edges)

median = cv2.medianBlur(image, 5)  
edges = cv2.Canny(median,100,200)
cv2.imshow('maxresdefault', edges)

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %%
import cv2
image= cv2.imread("maxresdefault.jpg")
cv2.imshow("maxresdefault", image)

gray= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)

median = cv2.medianBlur(gray, 5)  #Pour la netteté
edges = cv2.Canny(median,100,200) #Pour définir les contours
cv2.imshow('Contour image', edges)

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")
cv2.imshow('maxresdefault.jpg', image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)


median = cv2.medianBlur(image, 5)  
edges = cv2.Canny(median,100,200)
cv2.imshow('gray', edges)

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")
cv2.imshow("image",image)

gris = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("image gris",gris)

bord = cv2.Canny(gris,100,200)
cv2.imshow('bord', bord)

median = cv2.medianBlur(image, 5)  
bord = cv2.Canny(median,100,200)
cv2.imshow('contours', bord)

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")
cv2.imshow('maxresdefault.jpg', image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('maxresdefault.jpg', gray)

edges = cv2.Canny(gray,100,200)
cv2.imshow('maxresdefault.jpg', edges)

median = cv2.medianBlur(image, 5)  
edges = cv2.Canny(median,100,200)
cv2.imshow('maxresdefault.jpg', edges)

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")

cv2.imshow('Original photo', image)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Gray image', gray)

# nettoyage
median = cv2.medianBlur(image, 7)  
# 2*(image-0.5*median))


median = cv2.medianBlur(image, 5)  
edges = cv2.Canny(median,100,200)

cv2.imshow('image', edges)

# %% [markdown]
# ### Réponse de SIMON EMMA

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")
cv2.imshow('Image 1', image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)

median = cv2.medianBlur(image, 9)  
edges = cv2.Canny(median,100,200)
cv2.imshow('Image edges', edges)

# %% [markdown]
# ---
#
# ## Exercice 2
#
# **Énoncé**
#
# !!! note Exercice 2  (8 pts)
# On veut maintenant trouver le marqueur Aruco sur l'image.
#
# * Détectez le marqueur Aruco avec la librairie openCV et affichez-le sur l'image en couleurs.
# * Déterminez la largeur en pixels du marqueur et inscrivez-la ci-dessous.
#
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %%
import cv2
import numpy as np

image = cv2.imread("maxresdefault.jpg")

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Gray image', gray)

# Créer le dictionnaire de marqueurs et le détecteur
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détecter les marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)

    cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %%
# Créer le dictionnaire de marqueurs et le détecteur

import numpy as np
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)
parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détecter les marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

def position_simple(corner):
    x = y = 0
    for i in range(4):
        x += corner[i][0]
        y += corner[i][1]
    
    return (x/4,y/4)

# %% [markdown]
# ### Réponse de DURAND MARC

# %%
import cv2

image_originale = cv2.imread("maxresdefault.jpg")

aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

corners, ids, rejected = detector.detectMarkers(gray)

image_with_markers = image_originale.copy()
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
   
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %%
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)


corners, ids, rejected = detector.detectMarkers(gray)



image_with_markers = image.copy()
if ids is not None:
    print(corners)
    largeur_carre = corners[0][0][0][0]-corners[0][0][1][0]
    print(largeurp_carre)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de LAURENT JULES

# %%
import cv2
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)


corners, ids, rejected = detector.detectMarkers(gray)



image_with_markers = image.copy() 
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %%
image = cv2.imread("maxresdefault.jpg")
cv2.imshow("Maxresdefault", image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray image', gray)

aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détecter les marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %%
import cv2

image_originale = cv2.imread("maxresdefault.jpg")

aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

corners, ids, rejected = detector.detectMarkers(gray)

image_with_markers = image_originale.copy()
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %%
# Créer le dictionnaire de marqueurs et le détecteur
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détecter les marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %%
# Créer le dictionnaire de marqueurs et le détecteur
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détecter les marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %%
import cv2

image = cv2.imread("maxresdefault.jpg")

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Gray image', gray)


#Le dictionnaire de marqueurs et le détecteur
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détection des marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %%
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

cv2.imshow('Detected Markers', image)

corners, ids, rejected = detector.detectMarkers(gray)

image_with_markers = image.copy()
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image, corners, ids)

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %%
import cv2
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)
parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

image = cv2.imread("maxresdefault.jpg")
gris = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

corners, ids, rejected = detector.detectMarkers(gris)

cv2.aruco.drawDetectedMarkers(image, corners, ids)
cv2.imshow('Detected Markers', image)

print(corners)

537 - 502

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %%
import cv2

aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)


corners, ids, rejected = detector.detectMarkers(gray)

markers = image.copy() 
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(markers, corners, ids)
    
cv2.imshow('Detected Markers', markers)

if len(corners) > 0:
    for corner in corners:
        c = corner[0] #coin en haut à gauche 
        largeur_pixel = cv2.norm(c[0] - c[1]) #coin supérieur gauche moins coins supérieur droit
        print(largeur_pixel)

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %%
# Créer le dictionnaire de marqueurs et le détecteur
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détecter les marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

# %% [markdown]
# ### Réponse de SIMON EMMA

# %%
# Créer le dictionnaire de marqueurs et le détecteur
aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

# Détecter les marqueurs
corners, ids, rejected = detector.detectMarkers(gray)


# Dessiner les marqueurs sur l'image et l'afficher
image_with_markers = image.copy() # pour éviter de dessiner sur l'image
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

largeur_arucos = corners[0][0][0][0] - corners[0][0][1][0] # soustraction des coordonnées x des deux premiers points

print("Largeur ", largeur_arucos)

# %% [markdown]
# ---
#
# ## Exercice 3
#
# **Énoncé**
#
# !!! note Exercice 3 (7 pts)
#
# On veut maintenant trouver le visage du youtubeur sur l'image.
#
# * Après une rapide recherche sur le Web, détecter le visage sur l'image avec la librairie openCV (qui utilise une méthode nommée cascade de classificateurs de Haar) et encadrez-le sur l'image en couleurs.
# * Déterminer la largeur en pixels du visage et inscrivez-la ci-dessous.
#
#
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %%
import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_alt.xml")


image = cv2.imread('maxresdefault.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    image = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
cv2.imshow('image',image)
cv2.destroyAllWindows()

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_alt.xml")
image = cv2.imread("maxresdefault.jpg")
faces = face_cascade.detectMultiScale(image, scaleFactor=1.3, minNeighbors=5)
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
cv2.imshow('img',image)

# %% [markdown]
# ### Réponse de DURAND MARC

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.data.haarcascades("/content/haarcascade_frontalface_default.xml")
eye_cascade = cv2.data.haarcascades('/content/haarcascade_eye.xml')

def adjusted_detect_face(img):
    face_img = img.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 10)
        
    return face_img

def detect_eyes(img):
    eye_img = img.copy()
    eye_rect = eye_cascade.detectMultiScale(eye_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in eye_rect:
        cv2.rectangle(eye_img, (x, y), (x + w, y + h), (255, 255, 255), 10)
        
    return eye_img

img = cv2.imread("maxresdefault.jpg")
img_copy1 = img.copy()
img_copy2 = img.copy()
img_copy3 = img.copy()

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

face = adjusted_detect_face(img_copy1)
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face.jpg', face)

eyes = detect_eyes(img_copy2)
plt.imshow(cv2.cvtColor(eyes, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('eyes.jpg', eyes)

eyes_face = adjusted_detect_face(img_copy3)
plt.imshow(cv2.cvtColor(eyes_face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face+eyes.jpg', eyes_face)

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml')

img = cv2.imread('maxresdefault.jpg')
faces = face_cascade.detectMultiScale(img, scaleFactor=1.3, minNeighbors=5)

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

x = abs(x - y)

# %% [markdown]
# ### Réponse de LAURENT JULES

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +"haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_eye.xml")
def detect_faces(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5)
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    return img

def detect_eyes(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    eyes = eye_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5)
    for (x, y, w, h) in eyes:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    return img
img = cv2.imread("maxresdefault.jpg")
face_img = detect_faces(img.copy())
eye_img = detect_eyes(img.copy())


plt.imshow(cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB))
plt.title("Face Detection")
plt.show()

plt.imshow(cv2.cvtColor(eye_img, cv2.COLOR_BGR2RGB))
plt.title("Eye Detection")
plt.show()

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+ "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +"/Documents/4OS/haarcascade_eye.xml")

def adjusted_detect_face(img):
    face_img = img.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        print(x,y,w,h)
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 10)

    return face_img

def detect_eyes(img):
    eye_img = img.copy()
    eye_rect = eye_cascade.detectMultiScale(eye_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in eye_rect:
        cv2.rectangle(eye_img, (x, y), (x + w, y + h), (255, 255, 255), 10)
        
    return eye_img

img = cv2.imread("maxresdefault.jpg")
img_copy1 = img.copy()
img_copy2 = img.copy()
img_copy3 = img.copy()

cv2.imshow("Maxresdefault", img)
face = adjusted_detect_face(img_copy1)
cv2.imshow("Maxresdefault", face)

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_originale = cv2.imread("maxresdefault.jpg")

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

def adjusted_detect_face(img):
    face_img = image_originale.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 10)

    return face_img

img = cv2.imread('maxresdefault.jpg')

face = adjusted_detect_face(image_originale.copy)
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face.jpg', face)

cv2.imshow("image_originale", image_originale)

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %%
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")


def detect_faces(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5)
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    return img

img = cv2.imread('maxresdefault.jpg')
face_img = detect_faces(img.copy())


# Display results
plt.imshow(cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB))
plt.title("Face Detection")
plt.show()

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

def adjusted_detect_face(img):
    face_img = img.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 10)

    return face_img

img = cv2.imread('maxresdefault.jpg')
img_copy1 = img.copy()
img_copy2 = img.copy()
img_copy3 = img.copy()

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

face = adjusted_detect_face(img_copy1)
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face.jpg' , face)

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
#"/content/
def adjusted_detect_face(img):
    face_img = img.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 10)

    return face_img


img = cv2.imread('maxresdefault.jpg')
img_copy1 = img.copy()
img_copy2 = img.copy()
img_copy3 = img.copy()

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))


face = adjusted_detect_face(img_copy1)
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face.jpg', face)

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'./haarcascade_frontalface_default.xml')


def detect_faces(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5)
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    return img

img = cv2.imread('maxresdefault.jpg')
face_img = detect_faces(img.copy())

# Display results
plt.imshow(cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB))
plt.title("Face Detection")
plt.show()

corners, ids, rejected = detector.detectMarkers(gray)

image_with_markers = image.copy()
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image, corners, ids)

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %%
import cv2
image = cv2.imread("maxresdefault.jpg")
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
def detect_faces(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5)
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)
    return image
face_image = detect_faces(image.copy())
cv2.imshow(image, cv2.COLOR_BGR2RGB)
cv2.title("Face Detection")
cv2.show()

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")


def adjusted_detect_face(img):
    face_img = img.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 10)

    return face_img

def detect_eyes(img):
    eye_img = img.copy()
    eye_rect = eye_cascade.detectMultiScale(eye_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in eye_rect:
        cv2.rectangle(eye_img, (x, y), (x + w, y + h), (255, 255, 255), 10)
        
    return eye_img

img = cv2.imread("maxresdefault.jpg")
img_copy1 = img.copy()
img_copy2 = img.copy()
img_copy3 = img.copy()

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

face = adjusted_detect_face(img_copy1)
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face.jpg', face)

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %%
import numpy as np
import cv2

detectMultiScale (image, objects, scaleFactor = 1.1, minNeighbors = 3, flags = 0, minSize = new cv.Size(0, 0), maxSize = new cv.Size(0, 0))

cv2.data.haarcascades+"face.xml"
cv2.data.haarcascades+"eye.xml"
f_cascade = cv2.CascadeClassifier("face.xml")
e_cascade = cv2.CascadeClassifier("eye.xml")
image = cv2.imread("maxresdefault.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = f_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    image = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = e_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        cv2.imshow('image',image)
cv2.imshow('face', faces)

# %% [markdown]
# ### Réponse de SIMON EMMA

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

def adjusted_detect_face(img):
    face_img = img.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 5)
        
    return face_img, w

face, largeur_visage = adjusted_detect_face(image)
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face.jpg', face)

print("Largeur du visage:", largeur_visage)

# %% [markdown]
# ---
#
# ## Exercice 4
#
# **Énoncé**
#
# !!! note Exercice 4  (4 pts)
#
# En sachant que le marqueur imprimé faisait 12 cm de large, et en présumant que le marqueur et le visage sont placés à égale distance de la caméra, calculez la largeur du visage du youtubeur.
#
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %%
on fait la largeur en pixel du visage fois 12 cm divisé par la largeur en pixel ddu marqueur

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %% [markdown]
# ### Réponse de DURAND MARC

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %%
largeurp_visage=x
rapport_cm_pixel_carre = 12/largeurp_carre 
cm_visage = largeurp_visage*rapport_cm_pixel_carre

# %% [markdown]
# ### Réponse de LAURENT JULES

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %% [raw]
# Si marqueur = 12cm de large, alors 1cm = environ 2.91pixels, arrondi a 3
# Donc, comme visage = 76 pixels au carre, c'est egal a 25.33cm
#
#
# Aire car pk pas:
# Donc, comme visage = 76 pixels au carre, c'est egal a 25.33cm**2 = 641.69cm**2

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %%
import cv2
import numpy as np

image_originale = cv2.imread("maxresdefault.jpg")
gray = cv2.cvtColor(image_originale, cv2.COLOR_BGR2GRAY)

aruco_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)

parameters = cv2.aruco.DetectorParameters()
detector = cv2.aruco.ArucoDetector(aruco_dict, parameters)

corners, ids, rejected = detector.detectMarkers(gray)

image_with_markers = image_originale.copy()
if ids is not None:
    print(corners)
    cv2.aruco.drawDetectedMarkers(image_with_markers, corners, ids)
    
cv2.imshow('Detected Markers', image_with_markers)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

def adjusted_detect_face(img):
    face_img = image_originale.copy()
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)

    for (x, y, w, h) in face_rect:
        cv2.rectangle(face_img, (x, y), (x + w, y + h), (255, 255, 255), 10)

    return face_img

img = cv2.imread('maxresdefault.jpg')

face = adjusted_detect_face(image_originale.copy)
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
plt.show()
cv2.imwrite('face.jpg', face)

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %%
rapport_pixel_cm = 12/35
largeur_hypotétique_en_pixel_du_visage = 70
rapport_pixel_cm * largeur_hypotétique_en_pixel_du_visage

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %%
cm_visage == 0

cm_visage == (52*12)/36 
print(cm_visage)

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %% [markdown]
# ### Réponse de SIMON EMMA

# %%
largeur_arucos_cm = 12
largeur_visage_cm = (largeur_visage/largeur_arucos)*largeur_arucos_cm
print(largeur_visage_cm)

# %% [markdown]
# ---
#
# ## Exercice 5
#
# **Énoncé**
#
# ## B) Protocole de communication
#
# Repartons de la librairie vue en cours. On veut y ajouter un système de [broadcast](https://fr.wikipedia.org/wiki/Broadcast_(informatique)) qui sert à envoyer un message à tout le monde.
#
# Pour cela, on va réserver un ID de destinataire spécifique (ici 255) qui indiquera quand on lui adressera un message que l'on souhaite s'adresser à TOUS les destinataires.
#
# !!! note Exercice 5 (8 pts)
#
# * Modifier le programme pour qu'un message envoyé à l'utilisateur 255 :
#     * soit reçu par tout le monde
#     * ne renvoie pas d'accusé de réception
#
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        
# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = [-1]
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1

envoi_message(BroadcastId, exp_id, id_aruco_msg, data)
#envoi_message(id_dest, exp_id, id_aruco_msg, data)

# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)



# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de DURAND MARC

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %%
from microbit_radio_simu import *

seqNum = 0
#BroadcastId = 255 on supprime cette variable de la fonction envoie message pour ne pas avoir un destinataire specifique
def envoi_message(id_exped, id_category, payload):
    trame = [id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)
    

def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                #envoi_message(id_exped, id_dest, 255, []) ceci est la ligne qui envoie l'accusé de reception            
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de LAURENT JULES

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(id_dest):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if dest_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if (mon_id == id_dest or id_dest == 255) and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
if mon_id == id_dest:
    print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)
elif id_dest == 255:
    print("Message pour tout le monde de",  id_exped, "-- type", id_category, "-- Contenu :", payload)

# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack != 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 255
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 256, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = BroadcastId
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
        trame = [id_dest, id_exped, seqNum, id_category] + payload
        checksum = sum(trame)
        trame = trame + [checksum]
        radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
if BroadcastId == 255:
    dest_id  = 0
    while dest_id < 256:
        id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
        print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)
        id_dest = id_dest + 1

else:
    id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
    print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)
    print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
id_exp = 0
id_dest = 255
envoi_message(BroadcastId, id_exp, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(id_dest)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)




# Expéditeur
#print("Message acked", check_last_message_ack(id_exp))

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

#plus d'accuse de reception
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 255
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped):
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])
        

        if mon_id == id_dest and checksum_recu == checksum_calculé :
            if id_category != 255:
                envoi_message(id_exped, id_dest, 255, [])                
            return id_dest, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 1
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ### Réponse de SIMON EMMA

# %%
from microbit_radio_simu import *

seqNum = 0
BroadcastId = 255
def envoi_message(id_dest, id_exped, id_category, payload):
    trame = [id_dest, id_exped, seqNum, id_category] + payload
    checksum = sum(trame)
    trame = trame + [checksum]
    radio.send_int(trame)

def check_last_message_ack(id_exped): # inutile maintenant mais je laisse
    # Receive ack
    id_dest_ack, id_exped_ack, id_category_ack, _, received_seqNum = reception_message(id_exped)
    
    # Check ack
    global seqNum
    if received_seqNum == seqNum and id_category_ack == 255:
        seqNum = seqNum + 1
        return True
    return False
    
def reception_message(mon_id):
    trame = radio.receive_int()
    if trame :
        id_dest = trame[0]
        id_exped = trame[1]
        if id_exped == 0: # vérifie qui a envoyé le broadcast
            id_vrai = mon_id
            mon_id = BroadcastId
        received_seqNum = trame[2]
        id_category = trame[3]
        payload = trame[4:-1]
        checksum_recu =  trame[-1]
        
        checksum_calculé = sum(trame[:-1])

        if mon_id == 255 and checksum_recu == checksum_calculé :
            
            return id_vrai, id_exped, id_category, payload, received_seqNum
        
    return None, None, None, None, None

# Expéditeur
data = [5, 623, 212, 40]
id_aruco_msg = 12
exp_id = 0
dest_id  = 35
envoi_message(BroadcastId, exp_id, id_aruco_msg, data)


# Destinataire
id_dest, id_exped, id_category, payload, _ = reception_message(dest_id)
print("Message pour", id_dest,"de",  id_exped, "-- type", id_category, "-- Contenu :", payload)


# Expéditeur
print("Message acked", check_last_message_ack(exp_id))

# %% [markdown]
# ---
#
# ## Exercice 6
#
# **Énoncé**
#
# !!! note Exercice 6 (6 pts)
#
# <img src="https://user.oc-static.com/upload/2021/06/01/16225672656323_P2C5-3.png" alt="Modèles OSI et TCP/IP" width="700" >
#
# 1) D'après vous, dans quelle **couche du modèle OSI et du modèle TCP/IP** est géré le **broadcast** ?
#
#
# 2) En plus de ce système de broadcast, citez une **fonctionnalité supplémentaire** que l'on pourrait ajouter à ce protocole de communication, ainsi que sa couche correspondante dans le modèle OSI et dans le modèle TCP/IP.
#
#
#
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI :reseau             Couche TCP/IP :internet
# 2) Fonctionnalité :      Séquence et Ack                     Couche OSI :transport              Couche TCP/IP :transport

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : RÉSEAU       Couche TCP/IP :INTERNET
# 2) Fonctionnalité :                             Couche OSI :              Couche TCP/IP :

# %% [markdown]
# ### Réponse de DURAND MARC

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI :  réseau            Couche TCP/IP :application
# 2) Fonctionnalité :                             Couche OSI :  utilisateur           Couche TCP/IP :

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI :  Réseau            Couche TCP/IP : Accès au réseau
# 2) Fonctionnalité : radio                       Couche OSI : Physique         Couche TCP/IP : accès au reseau

# %% [markdown]
# ### Réponse de LAURENT JULES

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI :  2            Couche TCP/IP : 4
# 2) Fonctionnalité : Error Control                            Couche OSI : 2             Couche TCP/IP : 4

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : Reseau          Couche TCP/IP : Internet
# 2) Fonctionnalité :  Multicast                           Couche OSI : Réseau             Couche TCP/IP :Internet

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI :réseau              Couche TCP/IP :application
# 2) Fonctionnalité :                              Couche OSI :              Couche TCP/IP :

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : réseau             Couche TCP/IP : transport
# 2) Fonctionnalité : Routing                      Couche OSI : liasion de données             Couche TCP/IP :internet

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : Réseau             Couche TCP/IP :Transport
# 2) Fonctionnalité :  Encryption            Couche OSI :Couche présentation               Couche TCP/IP : Internet

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : Réseau       Couche TCP/IP :Tansport
# 2) Fonctionnalité :                             Couche OSI :              Couche TCP/IP :

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI :  réseau      Couche TCP/IP : transport
# 2) Fonctionnalité :                             Couche OSI :              Couche TCP/IP :

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : 3             Couche TCP/IP : internet
# 2) Fonctionnalité : Checksum                    Couche OSI : 7             Couche TCP/IP : Application

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : liaison des données       Couche TCP/IP :transport
# 2) Fonctionnalité :                             Couche OSI :              Couche TCP/IP :

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %% [raw]
# 1) Fonctionnalité : Broadcast                   Couche OSI : Réseau             Couche TCP/IP : Internet
# 2) Fonctionnalité : checksum                    Couche OSI : Transport          Couche TCP/IP : Transport

# %% [markdown]
# ### Réponse de SIMON EMMA

# %% [raw]
# 1) Fonctionnalité : Broadcast                 Couche OSI : Réseau         Couche TCP/IP : Internet
# 2) Fonctionnalité : Encryption                Couche OSI : Présentation   Couche TCP/IP : Application

# %% [markdown]
# ---
#
# ## Exercice 7
#
# **Énoncé**
#
# ## C) Machines d'États Finis
#
# On va finalement repartir du problème vu en cours en le complexifiant un peu :
#
# Lorsque le robot se trouve à plus de 150 pixels du marqueur, il avancera vers lui avec une vitesse élevée puis ralentira à une vitesse plus faible, avant de s'arrêter à 70 pixels.
#
# !!! note Exercice 7 (8pts)
#
# Dessinez sur l'énoncé la machine d'états et ses transitions.
#
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de DURAND MARC

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de LAURENT JULES

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ### Réponse de SIMON EMMA

# %% [markdown]
# *Aucune réponse détectée.*

# %% [markdown]
# ---
#
# ## Exercice 8
#
# **Énoncé**
#
# !!! note Exercice 8 (8pts)
#
# En partant du programme ci-dessous vu en cours, implémentez cette modification.
# !!!

# %% [markdown]
# ### Réponse de BERNARD LUC

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE_RAPIDE = "Approche rapide"
ETAT_APPROCHE_LENTE = "Approche lente"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse_rapide = 35
vitesse_lente = 20
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax and distance2 > 150:
            etat_actuel = ETAT_APPROCHE_RAPIDE
        elif abs(angle) < angleMax and distance2 <= 150:
            etat_actuel = ETAT_APPROCHE_LENTE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE_RAPIDE:
        motor_run(Motor.ALL, Vitesse_rapide,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
    elif etat_actuel == ETAT_APPROCHE_LENTE:
        motor_run(Motor.ALL, Vitesse_lente,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de DUPONT JEAN

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de DURAND MARC

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de GARCIA JULIE

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    angleMax, distanceMax, id_category, msg, seqNum = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de LAURENT JULES

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distance1 = 150
distance2 = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance1 : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de LEFEBVRE ANNE

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_APPROCHE_LENTE = "Approche lente"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
distanceSlow = 150
angleMax = 20
vitesseRotation = 35
vitesse = 50
vitesse_lente = 25
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            if distance2 < distanceSlow**2:
                etat_actuel = ETAT_APPROCHE_LENTE
            elif distance2 > distanceSlow**2:
                etat_actuel = ETAT_APPROCHE                   
        else:
            etat_actuel = ETAT_TOURNER
        
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        
    # Approche lente
    elif etat_actuel == ETAT_APPROCHE_LENTE:
        motor_run(Motor.ALL, vitesse_lente,Direction.FORWARD)   
        led_rgb(Color.CYAN)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de LEROY CLAIRE

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de MARTIN MARIE

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = distance2//2
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de MICHEL LOUIS

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        if distance2 < 90:
            etat_actuel = ETAT_APPROCHE_LENTE
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        
    elif etat_actuel == ETAT_APPROCHE_LENTE:
        motor_run(Motor.ALL, 15,Direction.FORWARD)   
        led_rgb(Color.BLUE)

        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de MOREAU PAUL

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de PETIT SOPHIE

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_RUN = "RUN"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"
ETAT_WALK = "WALK"

IdAruco = 42
distanceMax = 70
angleMax = 20
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < 70:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            if distance < 150:
                etat_actuel = ETAT_WALK
            else:
                etat_actuel = ETAT_RUN
                if 120 > distance > 90:
                    etat_actuel = ETAT_WALK
                elif distance = 70:
                    etat_actuel = ETAT_FINI
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_RUN:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        
    elif etat_actuel == ETAT_WALK:
        motor_run(Motor.RIGHT, 15)
        motor_run(Motor.LEFT, 15)
        leg_rgb(Color.YELLOW)

        
    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de RICHARD ALICE

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"
ETAT_VITE = "Vite"

IdAruco = 42
distanceMax = 70
distanceloin = 150
angleMax = 20
vitesseRotation = 35
vitesse = 35
vitesseMax = 75
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax:
            etat_actuel = ETAT_FINI
        elif distance2 > distanceloin:
            etat_actuel = ETAT_VITE
        elif distance2 < distanceloin and distance2 > distanceMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        
    # vite
    elif etat_actuel == ETAT_VITE:
        motor_run(Motor.ALL, vitesseMax(),Direction.FORWARD)   
        led_rgb(Color.YELLOW)
            
    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse(),Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de ROBERT PIERRE

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"
ETAT_RALENTIR = "RALENTIR"

IdAruco = 42
distanceMax = 70
distanceRal = 80
angleMax = 20
vitesseRotation = 35
vitesseRal = 15
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        elif distance2 < distanceRal:
             etat_actuel = ETAT_RALENTIR
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        
    elif etat_actuel == ETAT_RALENTIR:
        motor_run(Motor.ALL, vitesseRal,Direction.FORWARD)  
        led_rgb(Color.YELLOW)
    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de ROUX THOMAS

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 150
angleMax = 70
vitesseRotation = 35
vitesse = 35
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)

# %% [markdown]
# ### Réponse de SIMON EMMA

# %%
# Librairies
from microbit import *
from maqueen import *
import radio
from protocole import *
    
# États possibles
ETAT_TOURNER = "Tourner"
ETAT_APPROCHE = "Approche"
ETAT_STANDBY = "StandBy"
ETAT_FINI = "Fini"

IdAruco = 42
distanceMax = 70
distanceLent = 150
angleMax = 20
vitesseRotation = 35
vitesse = 35
vitesse_lente = 20
userId = 1

etat_actuel = ETAT_STANDBY


while True:        
    
    ####### Radio #######
    _, _, id_category, msg, _ = reception_message(userId) 
    if msg is not None and id_category == IdAruco:
        angle = msg[0]
        distance2 = msg[1]
        print("distance : ", distance2, "angle : ", angle)
        
        
    ####### Changement d'état #######
    if not msg :
        etat_actuel = ETAT_STANDBY
    else:        
        if distance2 < distanceMax**2:
            etat_actuel = ETAT_FINI
        elif abs(angle) < angleMax and (distanceLent+1)**2 > distance2 > distanceMax**2:
            etat_actuel = ETAT_APPROCHE_LENTE
        elif abs(angle) < angleMax and distance2 > distanceLent**2:
            etat_actuel = ETAT_APPROCHE
        else:
            etat_actuel = ETAT_TOURNER
            
    print("État actuel :", etat_actuel)
    
    
    ####### Application état #######
    # Tourner
    if etat_actuel == ETAT_TOURNER:
        motor_run(Motor.RIGHT, vitesseRotation, angle > 0)
        motor_run(Motor.LEFT, vitesseRotation, angle < 0)
        led_rgb(Color.BLUE)
        

    # Approche
    elif etat_actuel == ETAT_APPROCHE:
        motor_run(Motor.ALL, vitesse,Direction.FORWARD)   
        led_rgb(Color.YELLOW)
        
    # Approche lente
    elif etat_actuel == ETAT_APPROCHE_LENTE:
        motor_run(Motor.ALL, vitesse_lente,Direction.FORWARD)   
        led_rgb(Color.ORANGE)
        

    # Fini
    elif etat_actuel == ETAT_FINI:
        motor_stop()
        led_rgb(Color.GREEN)
        

    # Pas de message
    else :
        motor_stop()
        led_rgb(Color.RED)
            
    sleep(250)
