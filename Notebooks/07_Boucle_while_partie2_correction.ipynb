# %% [markdown]
# <div style="padding:20px;background-color:papayawhip;" >
# <h3 style="color:chocolate"> <i class="fa fa-info" aria-hidden="true"> </i> &nbsp; Remarque introductive &nbsp;  <i class="fa fa-info" aria-hidden="true"></h3>
# <p> Ce fichier est fait pour être lu sur le site <a href="https://notebook.basthon.fr/"><img src='https://notebook.basthon.fr/assets/efede5218c9087496f16.png' style="border: 0; display:inline; margin: 0 5px; height:30px" alt="Basthon"/></a>. <br>
#
# Si vous l'avez ouvert avec un autre programme, comme Jupyter notebook, vous riquez de rencontrer quelques bugs. <br>
# Veuillez cliquez sur <a href="https://notebook.basthon.fr/">ce lien</a> et y charger ce fichier à l'aide du bouton "Ouvrir"  &nbsp; <i class="fa fa-folder" aria-hidden="true"> </i>
# </p> </div>
#
#
#
#
# <div class = "alert  alert-danger">
#
# # Cours avec solution
# </div>

# %% [markdown]
# # 7.1 - Boucle `while`, partie 2
#
# Dans ce chapitre, nous allons apporter quelques compléments à la notion de boucle `while`. En particulier, nous discuterons des erreurs à éviter et de l'instruction `break`

# %% [markdown]
# ## Les pièges
#
# ### Piège 1: oublier d'initialiser les variables présentées dans la condition du `while`
#
# On veut un programme qui demande un mot de passe qui reste bloqué tant que le bon mot de passe n'est par fourni. On serait tenter d'écrire

# %%
while mot_de_passe != "123456" :
    mot_de_passe = input("Entrez le mot de passe : ")

# %% [markdown]
# Le programme génère une erreur, car pour tester la condition `mot_de_passe != "123456"`, la variable `mot_de_passe` doit d’abord être initialisée. En effet, il est impossible d’évaluer une variable qui n’a pas encore de valeur !

# %% [markdown]
# ```
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# NameError: name 'mot_de_passe' is not defined
# ```

# %%
mot_de_passe = ""  # Initialisation de la variable
while mot_de_passe != "123456" :
    mot_de_passe = input("Entrez le mot de passe : ")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 5: Saisie sécurisée </h3>
#
# Écrire un programme qui demande une note. Tant que la note saisie n’est pas valide (c’est-à-dire comprise entre 0 et 6), le programme redemande une saisie (utiliser la fonction `input`).
#
#
# <div class = "alert alert-block alert-warning">
#
# ### Solution
# </div>

# %%
# mon programme
note = -1  # pour faire au minimum une itération de la boucle
while note > 6 or note <0 :
    note = float(input("Entrez la note : "))

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### Solution avec l'intruction `break` qui permet de sortir d'une boucle
# </div>

# %%
# mon programme

while True :
    note = float(input("Entrez la note : "))
    if 0 <= note <= 6:
        break

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 6: Nombre dans un intervalle </h3>
#
# Écrire un programme qui demande un nombre entier.
# Tant que le nombre n’est pas compris entre 10 et 20 (inclus), le programme redemande une saisie.

# %%
# mon programme
nombre = 0
while nombre < 10 or nombre >= 20 :
    nombre = int(input("Entrez un nombre entre 10 et 20 : "))

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 7: Longueur minimale </h3>
#
# Écrire un programme qui demande à l’utilisateur de saisir un mot. Tant que le mot contient moins de 5 caractères, le programme redemande une nouvelle saisie.
#
# **Aide:**
# Vous pouvez utiliser la fonction `len(ma_variable)` qui permet d’obtenir la longueur d’une chaîne de caractères.
#
# Exemple à tester:
#
# ```
# texte = "soleil"
# nb_de_caractere = len(texte)
# print("le mot:", texte, "comporte:",nb_de_caractere, "caractères")
# ```

# %%
nb_de_caractere = 0               # initialisation de la variable permettant d'entrer dans la boucle

while nb_de_caractere < 5:
    texte = input("Saisir un texte de longueur > 5: ")
    nb_de_caractere = len(texte)

# %% [markdown]
# ### Piège 2: tomber dans une boucle infinie
#
# Il est fréquent d'oublier une ligne de code qui influence la condition d'arrêt, et d'écrire une boucle `while` qui ne se termine pas.
#
# Par exemple, dans le programme
#
# ```python
# n = 0
# while n < 10 :
#     print(n)
# ```
# La condition `n < 10` sera toujours vraie car on a oublié d'incrémenter la variable `n`. Il aurait fallut écrire
# ```python
# n = 0
# while n < 10 :
#     print(n)
#     n = n + 1
# ```

# %% [markdown]
# <h3 style="color:chocolate;background-color:papayawhip;" > <i class="fa fa-question" aria-hidden="true"> </i> &nbsp; Quizz </h3>
#
# Parmi les programme suivant choisi celui qui part en boucle infini.
#
#    <input type="checkbox" >  **Programme A**
# ```python
# i = A - 1
# while i < A :
#    i = i - 1
# ```
#    <input type="checkbox" >  **Programme B**
# ```python
# i = A + 1
# while i < A :
#    i = i - 1
# ```
#
#    <input type="checkbox" >  **Programme C**
# ```python
# i = A + 1
# while i < A :
#    i = i + 1
# ```
#
#    <input type="checkbox" >  **Programme D**
# ```python
# i = A - 1
# while i < A :
#    i = i + 1
# ```

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8">Programme A) car i est décrémenté, donc il devient de plus en plus petit et il ne dépassera jamais A et la condition i < A sera toujours vraie
# </div>
# </details>

# %% [markdown]
# ## Simuler l'exécution d'une boucle while
#
# Il est parfois difficile de debugger un programme avec une boucle `while`.  Dans cette optique, il est utile de simuler l'exécution de la boucle en notant l'évolution des variables et de la condition d'arrêt dans un tableau.
#
# <h3 > Exemple 3: Simuler l'exécution d'un programme</h3>
#
# Le programme suivant
#
# ```python
# n = 100
# p = 1
# while p < n:
#     p = 2 * p
#     print(p)
# ```
# Cherche la première puissance de 2 supérieure à un entier 𝑛 donné. La boucle fait prendre à 𝑝 les valeurs 2, 4, 8, 16, … Elle s’arrête dès que la puissance de 2 devient supérieure ou égale à 𝑛. Ainsi, dans ce cas, le programme affiche toutes les puissances jusqu’à 128 (incluse). Le déroulement de l’exécution est résumé dans le tableau ci-dessous :
#
# | `p`   |   `n`   | `p < n ` |
# | :---: |:-------:| :-------:|
# |   1   |  100    |   `True` |
# |   2   |  100    |   `True` |
# |   4   |  100    |   `True` |
# |   8   |  100    |   `True` |
# |   16  |  100    |   `True` |
# |   32  |  100    |   `True` |
# |   64  |  100    |   `True` |
# |   128 |  100    |   `False` |
#
# Dans les notebook, on peut toujours vérifier l'exécution d'un programme avec le module `tutor`.
#
# !!! info Utilisation de tutor
#
# Pou  exécuter un programme "pas à pas", il suffit d'importer le module `tutor` au début de votre programme avec l'instruction `from tutor import tutor` puis de terminer le programme avec l'instruction `tutor()`
# !!!
#
# **A faire:**
# Vérifier que le tableau ci-dessus est correct en éxécutant le programme ci-dessous:

# %%
from tutor import tutor

n = 100
p = 1
while p < n:
    p = 2 * p
    print(p)

tutor()

# %% [markdown]
# <h3 style="color:chocolate;background-color:papayawhip;" > <i class="fa fa-question" aria-hidden="true"> </i> &nbsp; Quizz </h3>
#
# Quelle est la valeur affichée (`print`) par le programme ci-dessous ?
#
# ```python
# u = 5
# n = 0
# while u != 656:
#     u = 5 * u + 1
#     n = n + 1
# print ( n )
# ```

# %% [raw]
# Réponse:

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8">C'est 3 car après 3 itérations  u vaut 656
# </div>
# </details>

# %% [markdown]
# <h3 style="color:chocolate;background-color:papayawhip;" > <i class="fa fa-question" aria-hidden="true"> </i> &nbsp; Quizz </h3>
#
# Quelle est la valeur affichée par le programme ci-dessous ?
#
#
# ```python
# u = 5
# v = 12
# i = 1
# while u < v:
#     u = 3 * u + 2
#     v = 2 * v + 3
#     i = i + 1
# print ( i )
# ```

# %% [raw]
# Réponse:

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8">C'est 3 car après 3 itérations  u vaut 656
# </div>
# </details>

# %% [markdown]
# <h3 style="color:chocolate;background-color:papayawhip;" > <i class="fa fa-question" aria-hidden="true"> </i> &nbsp; Quizz </h3>
#
# Quelle valeur faut-il donner à la variable `k` pour que le programme ci-dessous affiche 7?
#
#
# ```python
# k = int(input("Quel valeur pour k ? "))
# n = 0
# while k != 1:
#     n = n + 1
#     k = k / 2
# print ( n )
# ```

# %% [raw]
# Réponse:

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8">C'est 128. En effet il faut diviser 7 fois 128 par 2 pour avoir 1.
#
# </div>
# </details>

# %% [markdown]
# ---
#
# # 🎯 **Conclusion : Quand utiliser `while` ?**
#
# | Situation | `for` | `while` |
# |-----------|-------|---------|
# | Nombre d'itérations connu à l'avance | ✅ Oui | ❌ Non |
# | Nombre d'itérations inconnu (dépend d'une condition) | ❌ Non | ✅ Oui |
# | Répéter une action jusqu'à un événement spécifique | ❌ Non | ✅ Oui |
# | Interaction utilisateur (ex: attendre une entrée correcte) | ❌ Non | ✅ Oui |
# | Boucles infinies avec condition d’arrêt | ❌ Risqué | ✅ Plus adapté |
#
# ## 📌 **À retenir**
# - **Utilise `for`** lorsque **le nombre d'itérations est fixé** (ex: parcourir une liste, boucle de comptage).
# - **Utilise `while`** lorsque **la boucle dépend d’une condition** qui peut varier (ex: entrée utilisateur, événement aléatoire, suivi d'une valeur dynamique).
# - **Attention aux boucles infinies !** Toujours s'assurer que la condition de sortie est bien définie.
#
# 🚀 **Exercez-vous** en adaptant les exercices et en créant vos propres scénarios d'utilisation de `while` !
#
# ---

# %% [markdown]
# ## Pour aller plus loin...

# %% [markdown]
# <h3> Exemple 4: Décomposer en facteurs premiers</h3>
#
# Le programme suivant réalise la décomposition en facteurs premiers d'un nombre donné par l'utilisateur-trice.

# %%
nombre = int(input('Entrez un entier: '))
i = 2

print(nombre, "=", end=" ")

while i < nombre:
    if nombre % i == 0:   # % est le reste de la division entière
        print(i, "·", end=" ")
        nombre = nombre // i   # // correspond à la division entière
    else:
        i = i + 1

print(nombre)

# %% [markdown]
# <h3 > Exemple 5: En code binaire</h3>
#
# Le programme transforme l'entier en code binaire.

# %%
n = int(input('Entrez un entier: '))

code = ''
while n > 0:
    if n % 2 == 1:
        code = '1' + code
    else:
        code = '0' + code
    n = n // 2

print(code)

# %% [markdown]
# ## Sortir avec `break`
#
# Le mot-clé `break`, seul sur une ligne, permet de sortir d'une boucle.
# Souvent cette méthode est utilisée pour avoir une boucle où la condition est testée à la fin ou à l'intérieur de la boucle `while`.

# %%
while True:
    mot_de_passe = input("Entrez le mot de passe : ")
    if mot_de_passe == "123456":
        print("Mot de passe valide")
        break
    print("Mot de passe invalide")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 8:  nombre de chiffre d'un nombre </h3>
#
# Ecrire un programme qui demande un nombre entier à l'utilisateur puis affiche combien de chiffres sont nécessaires pour écrire ce nombre. Par exemple, le nombre entier 74613 s'écrit avec 5 chiffres.
#
# *Indication : Faites des divisions entières par 10 successivement*
#
# <div class = "alert alert-block alert-warning">
#
# ### Solution
# </div>

# %%
nombre = int(input("Entrez le nombre entier : "))
chiffres = 0 # le nombre de chiffre pour écrire "nombre"
while nombre != 0:
    nombre = nombre // 10
    chiffres = chiffres + 1
    
print("Il faut ", chiffres, "chiffres pour écrire ce nombre ")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 9:    Le trait qui tourne  </h3>
#
# 💡 **Objectif** : En répétant plusieurs fois je dessine un trait et je tourne d'un angle, je dessine une figure.
#
# Suivre les indications suivantes:
# - le stylo de couleur bleu avance sur un segment droit de longueur 5;
# - puis tourne de 70° vers la droite.
# - Ensuite, la longueur du segment est incrémentée (augmentée de 0.5).
# - Répéter ces étapes tant que la longueur du segment est inférieure à 150.
#
# 1. Ecrivez un programme qui suit les indications ci-dessus.
#
# 2. Modifiez le programme en utilisant une rotation de 89° au lieu de 70°.
#
# Vous devez obtenir les figures ci-dessous
# ![Image de tourbillon](https://githepia.hesge.ch/info_sismondi/exercices-1ere/-/raw/main/Notebooks/imgs_chap7/tourbillon.png)
#
#
#
# <div class = "alert alert-block alert-warning">
#
# ### Solution
# </div>

# %%
# version 1
from turtle import *

color("blue")

speed(0)

l = 5
while l < 150:
    forward(l)
    right(70)
    l = l + 0.5
    
done()

# %%
# version 1
from turtle import *

color("blue")

speed(0)

l = 5
while l < 150:
    forward(l)
    right(89)
    l = l + 0.5
    
done()

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 10:    Ratrapper la tortue </h3>
#
#
# Une tortue s'élance sur une piste de 10 mètres de long. Le jour, elle parcourt 1 mètre, la nuit, elle
# se repose.
#
# Seulement, voilà, la piste, en caoutchouc, s'étire toutes les nuits de 10 mètres. Ainsi, au deuxième
# matin, la tortue se retrouve à deux mètres du début de la piste, mais à 18 mètres de son extrémité.
#
# Lorsqu'elle s'endort le soir, il lui reste encore 17 mètres à parcourir. Et lorsqu'elle se réveille le matin suivant, la piste a 30 mètres de long, dont plus de 25 mètres sont
# devant elle!
#
#     a) La tortue arrivera-t-elle au bout de la piste?
#     b) Si oui, en combien de temps?
#     c) Rédiger un programme qui détermine le nombre de jours.
#
# *Indication : calculer la fraction de la piste que la tortue parcours chaque jour.*
#
# <div class = "alert alert-block alert-warning">
#
# ### Solution
# </div>

# %%
L = 10 #la longeur de la piste
p = 0 # la position en % par rapport au début (exemple à mi-chemin 50% donc p = 0.5)
jours = 0
while p < 1:
    p = p + 1/L # 1/L représente combien 1m correspond en % parcouru sur la piste de longeur L
    L = L + 10 # la piste s'allonge
    jours = jours + 1

print("il aura fallu ",jours, "jours à la tortue.")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 11:  La balle rebondissante </h3>
#
#
# Une balle rebondissante est lâchée du haut d'un immeuble de 10 mètres. A chaque rebond la hauteur diminue d'un tiers. Combien de fois la personne du premier niveau dont la fenêtre est située à 1 mètre 50 du sol verra elle passer la balle ?
#
#
#
# <div class = "alert alert-block alert-warning">
#
# ### Solution
# </div>

# %%
h = 10 # hauteur de la balle au départ

n = 0 # nb de fois la balle passe devant la fenêtre

while h >= 1.5:
    h = h - (1/3) * h
    if h >= 1.5: # si la balle rebondit au dessus de la fenêtre
        n = n + 2
    else:# si la balle rebondit en dessous de la fenêtre
        n = n + 1
        
print("La personne voit ", n, " fois la balle.")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 12:  La suite de Syracuse </h3>
#
# On définit une suite $u_n$ de la manière suivante :
#
# - $u_0 = 1000$
# - si $u_n = 1$, alors la suite est finie et u n est son dernier élément (on arrête de calculer d’autres
# éléments)
# - si $u_n$ est pair, alors $u_{n+1} = u_n / 2$
# - si $u_n$ est impair et distinct de 1, alors $u_{n+1} = 3 u_n + 1$
#
# Écrire un programme qui affiche les termes de la suite u.
#
# Cette suite est-elle finie ?
#
# Pour aller plus loin, aller vous renseigner sur la Conjecture de Syracuse https://fr.wikipedia.org/wiki/Conjecture_de_Syracuse.
#
#
#
# <div class = "alert alert-block alert-warning">
#
# ### Solution
# </div>

# %%
u = 1000
while u != 1:
    if u % 2 == 0: #si u est pair
        u = u / 2
    else:
        u = 3 * u + 1  
    print(u)

# %% [markdown]
# ---
#
# #### Remarque générale
#
# Ce document est une adaptation d'un ressource pédagogique tiré du catalogue modulo https://modulo-info.ch/. Il est sous license Creative Commons [BY-NC-SA](https://creativecommons.org/licenses/?lang=fr)
# ![Licence Creative Commons](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
