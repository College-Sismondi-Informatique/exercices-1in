# %% [markdown]
# <div style="padding:20px;background-color:papayawhip;" >
# <h3 style="color:chocolate"> <i class="fa fa-info" aria-hidden="true"> </i> &nbsp; Remarque introductive &nbsp;  <i class="fa fa-info" aria-hidden="true"></h3>
# <p> Ce fichier est fait pour être lu sur le site <a href="https://notebook.basthon.fr/"><img src='https://notebook.basthon.fr/assets/efede5218c9087496f16.png' style="border: 0; display:inline; margin: 0 5px; height:30px" alt="Basthon"/></a>. <br>
#
# Si vous l'avez ouvert avec un autre programme, comme Jupyter notebook, vous riquez de rencontrer quelques bugs. <br>
# Veuillez cliquez sur <a href="https://notebook.basthon.fr/">ce lien</a> et y charger ce fichier à l'aide du bouton "Ouvrir"  &nbsp; <i class="fa fa-folder" aria-hidden="true"> </i>
# </p> </div>

# %% [markdown]
# # 6 - Les Conditions
#
# Dans ce chapitre, nous allons voir comment un programme peut faire des choix, et comment il peut exécuter du code de façon sélective.
#
# <blockquote class="alert alert-info" style="background-color:rgb(220,240,255); margin:10px 10%;">
#     <p><span style="font-size:1.5em">❔</span> C'est quoi une instruction conditionnelle? Exécutez la cellule ci-dessous pour voir une petite introduction sur la notion de type d'instruction conditionnelle</p>
# </blockquote>
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/c0cm031r_eo?si=Apy9aC8a9HoHcHfv" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## I) Comparaisons
#
# Il est souvent nécessaire dans un programme de comparer deux valeurs.
# Python connait six types de comparaisons :
#
# - plus petit (`<`),
# - plus petit ou égal (`<=`),
# - égal (`==`),
# - différent (`!=`),
# - plus grand  (`>`),
# - plus grand ou égal (`>=`).
#
# Dans des formules mathématiques nous utilisons les symboles ≤,  ≥ et ≠. En Python vous devez utiliser deux symboles: `<=`, `>=` et `!=` à la place. Noter bien les différences !
#
# Le résultat d'une comparaison est une valeur **booléenne**, soit `True` (vrai) soit `False` (faux).
#
# ??? info  Que peut-on comparer en python ?
# - des nombres entiers (`5 < 10`), la réponse sera `True`
# - des nombres flottants (`5.68 == 7.12`), la réponse sera `False`
# - des nombres entiers et des nombres flottants (`5.68 < 5`), la réponse sera `False`
# - des chaînes de caractères `"arbre" < "arbuste"`, la réponse sera `True`(*)
# - des booléens (vous verrez des exemples plus tard)
#
# (*): python classe les chaînes de caractères et séquences par ordre alphabétique/valeur ASCII (majuscules avant minuscules) en comparant les éléments un par un.
#
# #### Erreur courante :
# Par contre, il est impossible de comparer des données de différentes natures (par exemple une chaîne de caractères avec un nombre).
#
# **C'est une erreur très fréquente lorsque l'on apprend à programmer !**
#
# ???

# %% [markdown]
# !!! example Exemple
#
# Qu'affiche le programme suivant ?
# ```python
# print(10 > 2)
# ```
# <form style="margin-top:10pt;" id="quiz1">
#   <label><input type="checkbox" name="A" value="correct"> True</label><br>
#   <label><input type="checkbox" name="B"> False</label><br>
#   <label><input type="checkbox" name="C"> Une erreur</label>
# </form>
# !!!

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8"> La valeur vraie (True) car l'expression 10 > 2 est vraie.
#
#
#
# </div>
#     <b>Ctrl+enter pour continuer ...........</b>
# </details>

# %% [markdown]
# !!! question Question
#
# En sachant que :
# ``` python
# a = 5
# b = 18
# c = 12.3
# mot1="Hello"
# mot2="World"
# ```
#
# **Indiquez la valeur booléenne `True` ou `False`  de chaque expression ou `Erreur` si la comparaison déclenche une erreur :**
#
# <!--<form style="margin-top:10pt;"  id="quiz2">
# <label> <code>a > 15</code> : <input type="text" id="False" value=""></label><br>
# <label> <code>a < a</code> : <input type="text" id="False" value=""></label><br>
# <label> <code>a <= a</code> : <input type="text" id="True" value=""></label><br>
# <label> <code>a+c > b</code> : <input type="text" id="False" value=""></label><br>
# <label> <code>c < "Hello"</code> : <input type="text" id="Erreur" value=""></label><br>
# <label> <code>mot1 != mot2</code> : <input type="text" id="True" value=""></label><br>
# </form>-->
#
# !!!

# %%
b >= a # True
a > 15 # 
a < a # 
a <= a # 
a+c > b # 
c < "Hello" # 
mot1 != mot2 #

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8">
#
# a > 15 : False
#
#
# a < a :False
#
# a <= a : True
#
#
# a+c > b : False
#
# c < "Hello" : Erreur
#
# mot1 != mot2 : True
#
#
# </div>
#     <b>Ctrl+enter pour continuer ...........</b>
# </details>

# %% [markdown]
# ## II) Conditions (`if`)
#
# Afin d'exécuter du code de façon sélective, on utilise le mot-clé `if`.
#
# Nous allons voir que :
#
# - le mot-clé `if` permet une exécution conditionnelle,
# - les mots-clé `if` et `else` permettent de choisir entre deux alternatives,
# - le mot-clé `elif` (else if) permet d'ajouter différentes conditions.

# %% [markdown]
# ### Exécution conditionnelle `if`
#
# La structure `if` ci-dessous permet d'exécuter une action seulement si `condition` est `True`.
#
# ``` python
# if condition:
#     action
# ```
#
# #### Exemple
#
# Le programme suivant demande la moyenne générale obtenue au premier semestre et affiche `Bravo, tu peux faire un extra-muros!` si la moyenne est supérieure ou égale à 5,3.

# %%
# Rappel: la fonction input permet d'intéragir avec le programme en saisissant une information au clavier.
n = float(input("Quelle est ta moyenne générale au premier semestre: "))

if n >= 5.3 :
    print("Bravo, tu peux faire un extra-muros!")

# %% [markdown]
# !!! question Quiz (Plusieurs réponses possibles)
#  #### En Python, l'instruction `if` est immédiatement suivi
#
# <form style="margin-top:10pt;" id="quiz3">
# <input type="checkbox" > d'un bloc (et)
#
# <input type="checkbox" value="correct" > d'une condition (et)
#
# <input type="checkbox" > de parenthèses (et)
#
# <input type="checkbox" value="correct" > d'un deux-points à la fin de la ligne (et)
# </form>
# !!!

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3c763d; border-radius:2pt; width:100%; color:#3c763d; padding:6px; background-color: #dff0d8">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3c763d; border-radius:2pt; color:#3c763d; padding:6px; background-color: #eff0e8"> d'une condition puis de d'un deux-points à la fin de la ligne suivis d'une indentation.
#
#
#
# </div>
#     <b>Ctrl+enter pour continuer ...........</b>
# </details>

# %% [markdown]
# ### Choix binaire `if - else`
#
# La structure `if - else` ci-dessous permet d'exécuter une **action_1** seulement si une **condition** est vraie et une **action_2** sinon :
#
# ``` python
# if condition:
#     action_1
# else:
#     action_2
# ```
#
# #### Exemple 1
# Dans l'exemple ci-dessous, on affiche si un nombre entré est positif ou négatif. Tester le programme avec différentes valeurs.

# %%
n = int(input('Entrez un nombre: '))

if n >= 0:
    print('positif')
else:
    print('négatif')

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 1 </h3>
#
# Complétez le programme qui demande son âge à l'utilisatrice et affiche `vous êtes majeure` si elle est majeure ou `vous êtes mineure` dans le cas contraire.
#
# *Rappel : la fonction `int` transforme la réponse textuelle du `input` en nombre entier.*

# %%
age = int(input("Bonjour, quel est votre âge ?"))

# compléter ici

# %% [markdown]
# #### Ctrl+enter pour continuer ...........

# %% [markdown]
# ### Choix multiple (`if - elif - else`)
#
# Le mot-clé `elif` est une contraction de **else if** et permet de continuer à tester d'autres conditions :
#
# ``` python
# if condition1 :
#     action_1
# elif condition2 :
#     action_2
# else:
#     action_3
# ```

# %% [markdown]
# Prenons un exemple du quotidien pour illustrer le choix multiple:
# <div><img alt="Choix multiple" src="https://raw.githubusercontent.com/College-Sismondi-Informatique/exercices-1in/refs/heads/main/Notebooks/imgs_chap6/poubelle.png?raw=true" style="width:400px"/></div>
# En python, le programme serait:

# %%
dechet = input('Quel est votre déchet ? [verre, papier ou autre]: ')

if dechet == 'verre':
    print('Jeter dans le bac vert')
elif dechet == 'papier':
    print('Jeter dans le bac bleu')
else:
    print('Jeter dans le bac gris')

# %% [markdown]
# Dans l'exemple ci-dessous, on affiche si un nombre entré est positif, négatif ou nul :

# %%
# N'oubliez pas int() permet de convertir la chaîne de caractère (str) provenant du input en entier (int).
n = int(input('Entrez un nombre: '))

if n > 0:
    print('positif')
elif n < 0:
    print('négatif')
else:
    print('zéro')

# %% [markdown]
# ??? info Exemples à éviter
#
# Sans le mot-clé `elif` nous devrions mettre le bloc `if` à l'intérieur du bloc  `else` en indentation.
# Avec multiples conditions, les blocs se décalent de plus en plus et rendent le programme illisible, comme ci-dessous.
#
# ``` python
# # L'exemple suivant s'exécute correctement mais c'est une mauvaise manière de programmer car moins lisible.
#
# n = int(input('Entrez un nombre: '))
#
# if n > 0:
#     print('positif')
# else:
#     if n < 0:
#         print('négatif')
#     else:
#         print('zéro')
# ```
#
# En prenant toujours le même exemple de départ, voici une autre manière de programmer qui n'est pas idéale. Elle oblige Python à évaluer toutes les conditions même si il a déjà testé une condition vraie.
#
# ``` python
# # L'exemple suivant s'exécute correctement mais c'est une mauvaise manière de programmer car moins efficace.
#
# n = int(input('Entrez un nombre: '))
#
# if n > 0:
#     print('positif')
# if n < 0:
#     print('négatif')
# if n ==0:
#     print('zéro')
# ```
# ???

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 2 </h3>
# Pour chacun des programmes:
#
# 1. Sans exécuter les programmes, trouver la valeur des variables demandées.
# 2. Vérifier votre réponse en ajoutant un `print(b)` à la fin des programmes et en les éxecutants.
#
# **Programme A**

# %%
# Programme A
a = 7
b = 12
if a > 5:
    b = b - 4
if b >= 8:
    b = b + 1

# %% [raw]
# La variable b vaut :

# %% [markdown]
# **Programme B**

# %%
# Programme B
a = 7
b = 12
if a > 5:
    b = b - 4
elif b >= 8:
    b = b + 1

# %% [raw]
# La variable b vaut :

# %% [markdown]
# **Programme C**

# %%
# Programme C
a = 7
b = 12
if a > 5:
    b = b - 4
else:
    b = b + 1

# %%
La variable b vaut :

# %% [markdown]
# **Programme D**

# %%
# Programme D
a = 10
if a < 5:
    a = 20
elif a < 100:
    a = 500
else:
    a = 0

# %% [raw]
# La variable a vaut :

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 3 </h3>
# Le programme suivant comporte beaucoup d'erreur, corrigez-les:

# %%
age == 18
revenu == 25000

if age >= 18
if revenu < 25000
print("Vous êtes éligible à la subvention.")
elif revenu < 26000
print("Vous êtes presque éligible à la subvention, vous gagnez 1'000.- de trop.")
else:
print("Vous n'êtes pas éligible à cause de vos revenus trop élevés.")
else:
if revenu < 25000
print("Vous n'êtes pas éligible à cause de votre âge, mais le seriez si vous étiez majeur·e.")
else:
print("Vous n'êtes pas éligible à cause de vos revenus trop élevés et de votre âge.")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 4 </h3>
#
# Écrivez un programme qui:
# 1. demande (utiliser input(...)) à l'utilisateur·ice s'il faut dessiner un triangle, un cercle ou un carré de dimension 100,
# 2. puis teste la réponse saisie
# 3. dessine la forme géométrique choisie.

# %%
from turtle import *





done()

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 5 </h3>
#
# Définissez une fonction `temperature()` qui prend en paramètre une température entre -20° [C] et +50°[C] et affiche si cette température est :
# * glaciale
# * froide
# * normale
# * chaude
# * bouillante
#
# **À vous de choisir les bornes de chaque catégorie**

# %%
def temperature(t):
    ...
    
    
    
    
temp = int(input("Entrez une température entre -20 et 50 : "))
temperature(temp)

# %% [markdown]
# #### Ctrl+enter pour continuer ...........

# %% [markdown]
# ### La différence entre `if` et `elif`
#
# Lorsqu'on utilise une structure conditionnelle avec `if`, `elif`, `else`, **le programme sort du bloc  dès qu'il trouve une condition vraie et que les instructions sous la condition sont exécutée**. C'est comme un **aiguillage de train** :
#
# - Le train (le programme) avance sur la voie principale (le `if`).
# - **Si** l'aiguillage (la condition `if`) est activé (vrai), le train dévie immédiatement sur cette voie et **ne teste pas les autres aiguillages** (`elif`, `else`).
# - **Sinon**, il continue tout droit vers la prochaine condition `elif`, puis éventuellement jusqu'au `else` s'il n'a trouvé aucun aiguillage actif.
#
# #### Exemple pour bien comprendre :
#
# ```python
# x = 10
#
# if x > 5:
#     print("Condition 1 : x est plus grand que 5")
# elif x > 3:
#     print("Condition 2 : x est plus grand que 3")
# else:
#     print("Condition 3 : aucune des conditions précédentes n'est vraie")

# %% [markdown]
# ### Ce qui se passe :
# - `x = 10` → La première condition `x > 5` est **vraie**, donc le message de la **Condition 1** s'affiche.
# - **Les autres conditions (`elif` et `else`) ne sont pas vérifiées du tout.**
# - Ensuite, le programme **poursuit son exécution après le bloc `if - elif - else`**, en continuant avec les instructions suivantes.
#
# Contrairement à une suite de `if` indépendants, le `if / elif / else` forme un seul bloc : **dès qu'une condition est vraie, on exécute son action et on ignore tout le reste.**

# %% [markdown]
# !!! warning  Erreur courante !
# Si la `condition1` est vraie (`True`), on exécute son `action_1` et on ignore tout le reste, on quitte le bloc ! Même si le `elif condition2` est vraie !!!!
#
# **Effectué l'`action_2` alors que l'on vient d'effectuer l'`action_1` est une erreur très fréquente lorsqu'on apprend à programmer !**
# !!!

# %%
x = 10
if x > 5:
    print("x est plus grand que 5")

if x > 3:
    print("x est aussi plus grand que 3")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 6</h3>
#
# Jean-Pierre a une hygiène de vie très stricte mais particulière. Il se pèse tous les matins
# - S’il pèse moins de 100 kilos, durant la journée, il ne boit que du coca.
# - S’il pèse entre 100 et 120 kilos, durant la journée, il ne boit que de jus d'orange.
# - S’il pèse entre 100 et 200 kilos, durant la journée il ne boit que de l’eau.
#
# Son épouse lui a écrit un programme python pour qu'il sache quoi boire.
# ```python
# poids = float(input("Quel est ton poids? "))
# print("Aujourd'hui, tu peux boire du", end=" ")
# if poids < 100:
#     print("coca")
# if poids < 120:
#     print("jus d'orange")
# if poids < 200:
#     print("eau")
# ```
#
# 1. Tester le programme (voir ci-dessous) avec les poids suivants : 78, 109, 130. Y-a-t'il un problème ?
#
# 2. Corriger le programme.

# %%
poids = float(input("Quel est ton poids? "))

print("Aujourd'hui, tu peux boire du", end=" ")
if poids < 100:
    print("coca")
if poids < 120:
    print("jus d'orange")
if poids < 200:
    print("eau")

# %% [markdown]
# #### Ctrl+enter pour continuer ...........

# %% [markdown]
# ## III) Les opérateurs `and`, `or` et `not`
#
# En plus des comparateurs (<, >, <=, >=, ==, !=), les opérateurs `and`, `or` et `not` permettent de manipuler plusieurs conditions :
# * `X and Y` Les deux conditions doivent être vraies pour que l'expression soit vraie.
# * `X or Y` Une des deux conditions doit être vraies pour que l'expression soit vraie.
# * `not X` La condition X doit être fausse pour que l'expression soit vraie.
#
# Testez le code suivant :

# %%
nombre = 15
if nombre > 10 and nombre < 20:
    print("Le nombre est entre 10 et 20.")
    

if nombre == 5 or nombre == 15:
    print("Le nombre est soit 15 soit 20.")
    
if not nombre > 15:
    print("Le nombre n'est pas supérieur à 15.")

# %% [markdown]
# <h6 style="color:chocolate;background-color:papayawhip;" > <i class="fa fa-warning" aria-hidden="true"> </i> &nbsp; Note </h6>
# En python, pour le premier cas :
#
# ``` python
# if nombre > 10 and nombre < 20:
#     print("Le nombre est entre 10 et 20.")
# ```
# on peut aussi écrire :
#
# ``` python
# if 10 < nombre < 20:
#     print("Le nombre est entre 10 et 20.")
# ```

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice 7 </h3>
#
#
# 1. Dire, pour chaque programme, si la condition est vraie.
#
# 2. Executer chaque programme pour vérifier votre réponse. Note : si la condition est vraie alors le texte `c'est vrai!` s'affiche.
#
# **Programme A**

# %%
x = 3
if not x < 2 or (x==3 and x != 5):
    print("C'est vrai!")

# %% [markdown]
# **Programme B**

# %%
x = 5
y = 12
if (not x < y or 3*x > y) and (not x==y or y < x):
    print("C'est vrai!")

# %% [markdown]
# **Programme C**

# %%
nationalite = "suisse"
age = 16
if not(age >= 18 and nationalite != "suisse") and (age > 20 or not nationalite == "suisse"):
    print("C'est vrai!")

# %% [markdown]
# #### Ctrl+enter pour continuer ...........

# %% [markdown]
# ## Exercices récapitulatifs

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 1 - Quizz </h3>
#
# Créez un quiz avec des questions à choix multiple sur un sujet de culture générale, dans le style des quiz sur le site Kahoot.
#
# - Complétez pour avoir **4 questions**
# - Ajoutez le calcul du score

# %%
print('Quiz sur le thème : ....')

score = 0

# Question 1 
print()
question = "Quel est le nom du cowboy dans Toy Story ?"
solution = 'Woody'

reponse = input(question)
if reponse == solution:
    ...
else:
    ...
    
    

# Question 2
print()
...


print('Votre score est', ...)

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 2a </h3>
#
# 1. Complètez le programme ci-dessous qui affiche `C'est un triangle rectangle` ou `Ce n'est pas un triangle rectangle` en fonction des longueurs des côtés du triangle rentré.
#
# 2. Testez votre programme pour vérifier si le triangle où a=9, b=12 et c= 15 est un triangle rectangle.
#
# *Rappel : Selon la réciproque du théorème de Pythagore, un triangle de longeur $a$, $b$ et $c$ ($c$ le plus grand côté) est rectangle si $a^2+b^2=c^2$*

# %%
a = float(input("La longeur du côté a vaut : "))
b = float(input("La longeur du côté b vaut : "))
c = float(input("La longeur du côté c vaut : "))

if ... :
    print("...")
else:
    print("...")

# %% [raw]
# Le triangle où a=9, b=12 et c= 15 est-il un triangle rectangle?
#
#     Réponse :

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 2b </h3>
#
# 1. Complètez le programme ci-dessous qui affiche `C'est un triangle rectangle` ou `Ce n'est pas un triangle rectangle` en fonction des longeurs des côtés du triangle rentré.
#
# **Attention à la différence de l'exercice 2a, ici rien ne garantie que c soit le plus grand côté.**
#
# 2. Testez votre programme pour vérifier que les triangles avec a=15, b=12 et c= 9, et a=5, b=3 et c= 4 sont des triangles rectangles.
#
# *Rappel : Selon la réciproque du théorème de Pythagore, un triangle de longeur $a$, $b$ et $c$ ($c$ le plus grand côté) est rectangle si $a^2+b^2=c^2$*

# %%
a = float(input("La longeur du côté a vaut : "))
b = float(input("La longeur du côté b vaut : "))
c = float(input("La longeur du côté c vaut : "))
if ... or ... or ... :
    print("...")
else:
    print("...")

# %% [raw]
# Le triangle où  a=15, b=12 et c= 9 est-il un triangle rectangle?
#
#     Réponse :
#
# Le triangle où  a=5, b=3 et c= 4 est-il un triangle rectangle?
#
#     Réponse :

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 3 </h3>
#
#
# Un client de boite de nuit est décrit par trois variables : son genre (“Masculin” ou “Féminin”), sa tenue (“Bien sapé”, “Mal sapé”) et son portefeuille (“Épais”, “Mince”).
#
# Les conditions pour rentrer en boîte de nuit sont les suivantes:
#
# - Un client pauvre mais bien sapé peut entrer.
# - Les clientes entrent toujours,
# - Un client pauvre et mal sapé n’entre pas.
#
# 1. Compléter les programme ci-dessous afin d'avoir une programme qui affiche `peut rentrer` ou `ne peut pas rentrer` en fonction du cas.
#
# 2. Testez le programme dans tous les cas évoqués.

# %%
genre = input("Quel est votre genre (masculin/féminin) : ")
tenue = input("Quel est votre tenue (bien sapé/mal sapé) : ")
portefeuille = input("Quel est votre portefeuille (epais/mince) : ")

# à compléter

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 4 </h3>
#
# 1. Complétez le programme ci-dessous qui demande à l'utilisateur·ice les coefficients d'une équation du second degré $ax^2+bx+c=0$ et qui affiche les solutions.
#
# 2. Testez votre programme sur les équations $5x^2-5x-15=0$, $5x^2-5x+15=0$ et $10x^2-20x+10=0$.

# %% [markdown]
# !!! info utiliser des fonctions mathématiques comme la fonction racine carrée $\sqrt{x}$.
# Pour calculer la racine carrée d'un nombre $\sqrt{x}$, il faut utiliser la fonction `sqrt` du module `math`. Pour ce faire, votre programme doit commencer par `from math import sqrt` (pour importer la fonction `sqrt` du module `math`).  Pour l'utiliser, il suffit de mettre la valeur dont on veut trouver la racine en argument de la fonction `sqrt`. Par exemple, l'instruction `print(sqrt(25))` affichera 5.
# !!!

# %%
a = ...(input("Entrer le coefficient a = "))
b = ...(input("Entrer le coefficient b = "))
c = ...(input("Entrer le coefficient c = "))
delta = ...
if ... :
    x1 = ...
    x2 = ...
    print("Deux solutions, x1= ",x1, "; x2 = ", x2)
elif ... :
    x = ...
    print("...")
else :
    print("...")

# %% [raw]
# Quel est l'ensemble des solution de 5x²-5x-15=0?
#
#     Réponse: S = ...
#
#
# Quel est l'ensemble des solution de 5x²+5x+15=0=0?
#
#     Réponse: S = ...
#
#
# Quel est l'ensemble des solution de 10x²-20x+10=0?
#
#     Réponse: S = ...

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 5 </h3>
#
# <b style="color:chocolate;background-color:papayawhip;" > <i class="fa fa-warning" aria-hidden="true"> </i> &nbsp; Rappel : L'opérateur modulo (%) calcule le reste de la division entière.  En conséquence, x % y vaut 0 quand x est divisible par y. <i class="fa fa-warning" aria-hidden="true">  </i> </b>
#
#
# Écrivez un petit programme qui demande à l'utilisateur·ice un nombre et indique s'il est pair (divisible par 2) ou pas.

# %%
# programme à compléter

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 6 </h3>
#
# Écrire un programme qui traduit chacune des situations ci-après. Chaque programme commence par demander l'âge de Camille, Antoinette et Bernard.
#
# **Situation 1 :**  Si Camille est plus âgée qu’Antoinette ou que Bernard et si Antoinette est plus jeune que Bernard, on affiche l’âge d’Antoinette, mais si Antoinette a le même âge ou est plus âgée que Bernard, on affiche l’âge de Bernard.
# Sinon on  affiche l’âge de Camille.

# %%
age_camille = int(input("Quel est l'age de Camille : "))
age_antoinette = # a compléter
age_bernard = # a compléter

# a compléter ...

# %% [markdown]
# **Situation 2:**  Si Bernard et Camille ont le même âge, on affiche l’âge de la plus jeune des trois personnes.

# %%
# programme pour la situation 2

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 7 </h3>
#
# Définissez une fonction `compare` qui prend en paramètres deux nombres `a` et `b`, puis qui dit lequel est le plus grand :
# - si le premier nombre est plus grand que le deuxième, le programme affichera « Le premier ! »
# - si le deuxième nombre est plus grand que le premier, le programme affichera « Le deuxième ! »
# - s'ils sont égaux, le programme affichera « Ils sont égaux. ».
#
#
# Testez-la avec deux nombres de votre choix.

# %%
# programme à compléter

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 8 </h3>
# Corrigez le programme suivant :

# %%
age == 18
revenu == 25000

if age >= 18
if revenu < 25000
print("Vous êtes éligible à la subvention.")
elif revenu < 26000
print("Vous êtes presque éligible à la subvention, vous gagnez 1'000.- de trop.")
else:
print("Vous n'êtes pas éligible à cause de vos revenus trop élevés.")
else:
if revenu < 25000
print("Vous n'êtes pas éligible à cause de votre âge, mais le seriez si vous étiez majeur·e.")
else:
print("Vous n'êtes pas éligible à cause de vos revenus trop élevés et de votre âge.")

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 9 </h3>
#
# Écris une fonction bissextile dont l'argument est une année  n, qui dit si cette année est bissextile (c'est-à-dire qu'elle comporte un 29 février).
# Une année est bissextile dans l'un des cas suivants :
# - c'est un multiple de 4 qui n'est pas un multiple de 100,
# - c'est un multiple de 400.
#
# Le programme doit afficher « Année bissextile » ou « Année non bissextile » suivant le cas.

# %%
# programme à compléter

# %% [markdown]
# <h3 style="color:teal;background-color:azure;" > <i class="fa fa-pencil" aria-hidden="true"> </i> &nbsp; Exercice récapitulatif 10 </h3>
#
# Définissez une fonction `compare` qui prend en paramètres deux nombres `a` et `b`, puis qui dit lequel est le plus grand :
# - si le premier nombre est plus grand que le deuxième, le programme affichera « Le premier ! »
# - si le deuxième nombre est plus grand que le premier, le programme affichera « Le deuxième ! »
# - s'ils sont égaux, le programme affichera « Ils sont égaux. ».
#
#
# Testez-la avec deux nombres de votre choix.

# %%
# programme à compléter

# %% [markdown]
# ---
#
# #### Remarque générale
#
# Ce document est une adaptation d'un ressource pédagogique tiré du catalogue modulo https://modulo-info.ch/. Il est sous license Creative Commons [BY-NC-SA](https://creativecommons.org/licenses/?lang=fr)
# ![Licence Creative Commons](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
