# %% [markdown]
# <div style="padding:20px;background-color:papayawhip;" >
# <h3 style="color:chocolate"> <i class="fa fa-info" aria-hidden="true"> </i> &nbsp; Remarque introductive &nbsp;  <i class="fa fa-info" aria-hidden="true"></h3>
# <p> Ce fichier est fait pour être lu sur le site <a href="https://notebook.basthon.fr/"><img src='https://notebook.basthon.fr/assets/efede5218c9087496f16.png' style="border: 0; display:inline; margin: 0 5px; height:30px" alt="Basthon"/></a>. C'est ce logo qui doit s'afficher en haut à gauche de cette fenêtre. <br>
#
# Si vous l'avez ouvert avec un autre programme, comme Jupyter notebook, vous riquez de rencontrer quelques bugs. <br>
# Veuillez ouvrir l'énoncé et y charger ce fichier à l'aide du bouton "Ouvrir"  &nbsp; <i class="fa fa-folder" aria-hidden="true"> </i>
# </p>
#
# Attention: **veillez à bien sauvegarder votre travail avec le bouton <i class='fa fa-save'></i>** dans le bon dossier du disque réseau (dossier document) avec le bon nom (et l'extension *.ipynb*), **sinon toutes les modifications seront perdues!**</div>

# %% [markdown]
# # 1. Premier programme, premières instructions

# %% [markdown]
# Dans ce chapitre, nous explorons ce que c’est un programme et nous prenons principalement l’exemple du dessin.
#
#
# <blockquote class="alert alert-info" style="background-color:rgb(220,240,255); margin:10px 10%;">
#     <p><span style="font-size:1.5em">❔</span> C'est quoi un programme ? La programmation? Regardez la vidéo suivante pour avoir la réponse.</p>
# </blockquote>
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7b3QupZc08Y?si=grHrbyxNcD3rf4kU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# !!! info Avant-propos : Les Notebooks
#
# L'environnement que vous avez sous les yeux se nomme  ***Basthon notebook***.
#
# **Un notebook est une suite de cellules** contenant, soit du **texte**, soit du **code**.
#
# - Les cellules de code sont facilement reconnaissables, elles sont précédées de `Entrée [ ]:`
# - La cellule qui suit celle que vous êtes en train de lire est une cellule de code.
# - Pour exécuter (évaluer) une cellule de code, il faut la sélectionner (un trait bleu ciel, gras et vertical est alors à sa gauche) :
#     - puis utiliser l'icone  <button class='fa fa-step-forward'> Exécuter</button>, qui vous fait passer d'une cellule à la suivante en affichant le résultat de l'exécution;
#     - ou enfoncer simultanément les touches <span><kbd><span style="color:white;background-color:gray" ><b> ⇧ Maj </b></span></kbd></span> et <span><b><kbd><span style="color:white;background-color:gray" > ↲ Entrée </span></kbd></b></span>.</div>
#
# !!!
#
#
# !!! example
# Entrainez-vous en **exécutant** la cellule de type ***code*** ci-dessous avec <span><kbd><span style="color:white;background-color:gray" ><b> ⇧ Maj </b></span></kbd></span> + <span><b><kbd><span style="color:white;background-color:gray" > ↲ Entrée </span></kbd></b></span>
# !!!

# %%
print("J'ai ", 2025-1982, "ans")

# %% [markdown]
# La cellule `Sortie` contient le résultat de l'exécution du fragment python, soit ci-dessus `J'ai  43 ans`.
#
# Pour ce cours, vous pouvez considérer les *notebooks* comme les chapitres d'un manuel de cours interactif. Tous les programmes de ce manuel peuvent être exécutés (comme vous l'avez fait ci-dessus) pour voir leur résultat et modifiés. Pour garder vos modifications d'un cours à l'autre, il faudra sauvegarder le notebook dans votre dossier personnel.
#
#
# !!! warning Il faut constament enregistrer son travail
#
# Sauvegardez régulièrement votre travail en cliquant sur le bouton <i class='fa fa-save icon-save btn btn-xs btn-default' style="padding:5px 10px"></i>
#
# Utilisez comme nom de fichier `Exercice_xx.ipynb` où `xx` est le numéro de la leçon. Il faut mettre l'extension `ipynb` qui signifie que le fichier contient un notebook Python.
#
# Pour ne pas perdre le fichier, il faut l'enregistrer dans votre dossier `Documents/Info_1ere/Python/`.
# Si vous désirez continuer depuis chez vous, il suffit de copier le fichier d'exercice ipynb dans votre Drive (google) accessible depuis la page https://eduge.ch
#
# !!!
#
# Voilà, vous en savez assez sur l'environnement ***Basthon notebook***. Vous pouvez accéder depuis l'école ou depuis chez vous à l'aide d'un navigateur web (Mozilla Firefox, Google Chrome, Safari, etc.).

# %% [markdown]
# !!! note Exercice 0
#
# La cellule ci-dessous contient le code d'un programme. Il n'est pas important de comprendre le programme. Ici, il s'agit d'apprendre à utiliser l'environnement Basthon notebook.
#
# 1. Cliquer sur la cellule pour la sélectionner, puis exécutez-la pour voir son résultat.
#
# 2. Sélectionnez-la à nouveau, et dans la ligne `n = 3`, remplacez 3 par 5, puis exécutez-la à nouveau pour voir le nouveau résultat.
#
# !!!

# %%
from turtle import *

n = 5


for _ in range(n):
    forward(100)
    left(360//n)

done()

# %% [markdown]
# Si vous ne vous êtes pas trompé⋅e dans le changement demandé, vous devriez maintenant voir un pentagone (polygone qui a cinq côtés.) sous la cellule. Pour ne pas perdre vos modifications, **sauvegardez le notebook dans le bon dossier avec un nom approprié** (n'oubliez pas l'extension .ipynb).

# %% [markdown]
# ## 1.0 Le module `robot`
#
# C'est maintenant le moment d'étudier vos premiers programmes **Python** et d'étudier les bases du fonctionnement du langage Python. Dans ce chapitre, nous explorons ce que c’est un programme et nous prenons un exemple de déplacement d'un robot où le programme est une séquence d’instructions pour le guider jusqu'à sa cible.
#
# Ci-dessous, vous trouvez notre premier programme de trois lignes :
#
# - dans la première ligne, l’expression `from robot import *` importe les fonctions de déplacement du robot,
#
# - avec `exoRobot1_0()`, on lance le 1er exercice,
#
# - `gauche(1)` permet de le faire se déplacer d'une case vers la gauche.
#
# Évidemment, des fonctions `droite(n)`, `haut(n)` et `bas(n)` sont également disponible pour les autres directions.

# %% [markdown]
# !!! note Exercice 1
#
# 1. Testez le programme ci-dessous.
# 2. Changez le paramètre de la fonction `gauche` (valeur entre parenthèses) pour l'amener jusqu'au drapeau.
#
# !!!

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Rappel:</b> Cliquez, soit sur le bouton <b>Excécuter</b>, soit sur les touches <b>Shift + Enter</b>, pour tester le programme. </div>

# %%
from robot import *
exoRobot1_0()

gauche(2)

# %% [markdown]
# !!! note Exercice 2
#
# Utilisez les fonctions `gauche(n)`, `droite(n)`, `haut(n)` et `bas(n)` avec les bons paramètres pour guider le robot jusqu'à son drapeau.
#
# !!!

# %%
from robot import *
exoRobot1_1()
haut(1)
gauche(2)
bas(2)

# %% [markdown]
# !!! note Exercice 3
#
# Utilisez les fonctions `gauche(n)`, `droite(n)`, `haut(n)` et `bas(n)` avec les bons paramètres pour guider le robot jusqu'à son drapeau.
#
# !!!

# %%
from robot import *
exoRobot1_2()
gauche(1)
bas(5)
gauche(1)

# %% [markdown]
# ## 1.1 Le module `turtle`
#
# Utilisons maintenant la programmation comme une séquence d’instructions pour dessiner une image.
#
# Dans le langage de programmation Python, le module `turtle` (signifiant tortue en anglais) présente une façon sympathique pour faire des dessins. C’est pour cela que nous commençons notre aventure de programmation avec cet animal qui avance tout doucement à son propre rythme.
#
# On s’imagine une tortue qui se déplace sur un canevas et laisse une trace.
#
# Ci-dessous, vous trouvez notre premier programme de cinq lignes :
#
# - dans la première ligne, l’expression `from turtle import *` met à disposition les fonctions de dessin,
#
# - avec `shape('turtle')`, nous affichons une tortue (au lieu de la flèche),
#
# - avec `forward(150)`, nous faisons avancer la tortue de 150 pixels,
#
# - avec `left(90)`, nous faisons tourner à gauche la tortue de 90 degrés,
#
# - avec `done()`, nous lançons de tracage de la figure.

# %% [markdown]
# !!! note Exercice 4
#
# 1. Testez le programme ci-dessous.
# 2. Ajoutez d’autres instructions afin de dessiner un carré de taille 150 × 150.
#
# !!!

# %%
from turtle import *

shape('turtle')
forward(150)
left(90)
forward(150)
left(90)
forward(150)
left(90)
forward(150)


done()

# %% [markdown]
# ### À retenir
# La première instruction du programme doit être
# - `from turtle import *` pour importer toutes les fonctions qui permettent de dessiner avec la tortue
#
# La dernière instruction du programme doit être
# - `done()` afin que d'indiquer que la tortue doit commencer à tracer la figure avec les instructions donnés préalablement.
#
# La tortue peut se déplacer et dessiner une trace avec les 2 fonctions:
#
# - `forward(d)` pour avancer d'une distance `d` (en pixels)
# - `left(a)` pour tourner à gauche d'un angle `a` (en degrés)

# %% [markdown]
# ***
# ## 1.2 Une séquence
#
# Un programme est une séquence d'instructions. Le bloc de 8 instructions ci-dessous indique comment dessiner un carré. La tortue doit avancer, tourner, avancer, tourner, etc.

# %% [markdown]
# !!! note Exercice 5
#
# Modifiez ce code pour en faire un rectangle, au lieu d'un carré.
#
# !!!

# %%
from turtle import *

forward(150)
left(90)
forward(100)
left(90)
forward(150)
left(90)
forward(100)
left(90)


done()

# %% [markdown]
# !!! note Exercice 6
#
# Complétez le programme ci-dessous afin qu'il dessine un losange conformément au croquis ci-dessous.
#
# ![Image de losange](https://github.com/College-Sismondi-Informatique/exercices-1in/blob/main/Notebooks/imgs_chap1/exo_losange.png?raw=true)
#
# !!!

# %%
from turtle import *

left(30)
forward(100)
left(120)
forward(100)
left(60)
forward(100)
left(120)
forward(100)



done()

# %% [markdown]
# ***
#
# ## 1.3 Épaisseur de ligne
#
# La fonction `width(d)` (épaisseur en anglais) permet de définir l'épaisseur de la ligne.
# Voici un triangle où chaque côté a une épaisseur différente.

# %% [markdown]
# !!! note Exercice 7
#
# Explorez différentes épaisseurs de ligne.
#
# !!!

# %%
from turtle import *

forward(200)
left(120)

width(5)
forward(200)
left(120)

width(100)
forward(200)

done()

# %% [markdown]
# ***
#
# ## 1.4 Maison avec toit
#
# Nous dessinons une maison et marquons le toit par une ligne plus épaisse.

# %% [markdown]
# !!! note Exercice 8
#
# Doublez l'épaisseur du toit. Ensuite, doublez la hauteur de la maison.
#
# !!!

# %%
from turtle import *

forward(100)
left(90)
forward(120)
left(45)
width(10)
forward(71)
left(90)
forward(71)
width(1)
left(45)
forward(120)
left(90)

done()

# %% [markdown]
# ## 1.7 Commentaire
#
# Le symbole `#` indique un commentaire. Sur PC vous pouvez l'insérer avec **Alt Gr+3** ou **opt+3** sur Mac.
# Un commentaire permet d'ajouter une explication pour le lecteur humain. Il n'a aucune influence sur le programme. Python ignore tout simplement tout commentaire.

# %% [markdown]
# !!! note Exercice 9
#
# Expliquez dans chaque ligne ce que fait l'instruction.
#
# !!!

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Astuce :</b> Utiliser les raccourcis <b>Ctrl + c</b> pour copier du texte et  <b>Ctrl + v</b> pour coller le texte copié. </div>

# %%
from turtle import *

width(50)       # mettre l'épaisseur du trait à 50
forward(20)     # avancer de 20 pas
width(10)       # mettre l'épaisseur du trait à 10
forward(60)     # avancer de 60 pas
width(50)       # mettre l'épaisseur du trait à 50
forward(20)     # avancer de 20 pas
width(10)       # mettre l'épaisseur du trait à 10
forward(40)     # avancer de 40 pas
left(45)        # pivoter de 45°
forward(60)     # avancer de 60 pas

done()

# %% [markdown]
# L'exercice précédent servait à expliciter pour un débutant en programmation la signification des commandes écrites en anglais. Normalement on ne fait pas ça, car un programmeur est censé connaitre la signification des commandes.
#
# Les commentaires servent à expliciter la vraie signification d'une partie du programme.

# %% [markdown]
# !!! note Exercice 10
#
# Expliquez cette fois ce que dessine chaque partie du programme (verre, pont, verre, charnière, branche).
#
# !!!

# %%
from turtle import *

# dessiner le premier verre
width(50)       
forward(20)

# dessiner le pont (nez)
width(10)       
forward(60)

#dessiner le deuxième verre
width(50)
forward(20)
width(10)

#dessiner la branche 
forward(40)
left(45)
forward(60)

done()

# %% [markdown]
# ## Exercices d'entraînement

# %% [markdown]
# !!! note Exercice 11
#
# Dessinez un hexagone régulier dont la longueur des côtés vaut 100 (voir la figure ci-dessous).
#
# !!!

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." />

# %% [markdown]
# *Exercice tiré du livre **L'informatique simplement** de J. Hromkovic et T. Kohn*

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b> Indication</b>
#     <br>
# Pour tracer un hexagone, la tortue doit tourner 6 fois. Comme un tour complet représente 360°, à chaque angle la tortue doit tourné de \( \frac{360}{6}=60 \) degrés.
#  </div>

# %%
from turtle import *

forward(100)
left(60)
forward(100)
left(60)
forward(100)
left(60)
forward(100)
left(60)
forward(100)
left(60)
forward(100)
left(60)


done()

# %% [markdown]
# !!! note Exercice 12
#
# Dessinez une chaise.
#
# !!!

# %%
from turtle import *

left(90)
forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(180)
forward(200)

done()

# %% [markdown]
# !!! note Exercice 13
#
# Commenter le programme ci-dessous afin d'expliquer le but des différents blocs du code.
#
# !!!

# %%
from turtle import *

# dessiner le grand rectangle
forward(200)
left(90)
forward(100)
left(90)
forward(200)
left(90)
forward(100)
left(90)

# avancer de 30 pas
forward(30)

# dessiner le petit rectangle
forward(30)
left(90)
forward(50)
left(90)
forward(30)
left(90)
forward(50)
left(90)

done()

# %% [markdown]
# !!! note Exercice 14 *
#
# Écrivez un programme qui dessine une maison comme dans le schéma ci-dessous. Elle est formée de plusieurs triangles isocèles rectangles. La longueur des côtés du carré de base est de 185.
#
# ![Image de maison](https://framagit.org/mschiess/1IN_Sismondi/-/raw/main/imgs_chap1/exo_maison.png)
#
# *Exercice tiré du livre **L'informatique simplement** de J. Hromkovic et T. Kohn*
#
# !!!

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b> Indication</b>
#     <br>
# pour connaître la longueur du toit et des diagonales, utilisez le théorème de Pythagore.
#  </div>

# %%
from turtle import *

# carré
forward(185)
left(90)
forward(185)
left(90)
forward(185)
left(90)
forward(185)

# Croix
left(90+45)
forward(262)
right(90+45)
forward(185)
right(90+45)
forward(262)

# Toit
right(45+30)
forward(185)
right(180-60)
forward(185)


done()

# %% [markdown]
# ---
#
# #### Remarque générale
#
# Ce document est une adaptation d'une ressource pédagogique tiré du catalogue modulo https://modulo-info.ch/ ainsi que d'un NB de M. Andjekel du [Lycée Levavasseur](https://www.levavasseur.xyz). Il est sous license Creative Commons [BY-NC-SA](https://creativecommons.org/licenses/?lang=fr)
# ![Licence Creative Commons](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
